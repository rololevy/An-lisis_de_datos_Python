# %% [markdown]
# ### Módulo 3 Análisis Exploratorio de Datos(EDA)

# %% [markdown]
# #### Lectura de fuentes de datos
#
# 120 años de olimpiadas: https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
import pandas as pd
import seaborn 
import matplotlib.pyplot as plt

# %%
olympics = pd.read_csv(r"..\datasets\03-analisis-exploratorio\olympics.csv")
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics.columns
# Out:
# Index(['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games',
#        'Year', 'Season', 'City', 'Sport', 'Event', 'Medal'],
#       dtype='object')

# %%
olympics.index
# Out:
# RangeIndex(start=0, stop=271116, step=1)

# %%
olympics.shape
# Out:
# (271116, 15)

# %% [markdown]
# Tipo de variables info

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %% [markdown]
# Cantidad y porcentaje de nulos

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics.isnull().head()
# Out:
#       ID   Name    Sex    Age  Height  Weight   Team    NOC  Games   Year  \
# 0  False  False  False  False   False   False  False  False  False  False
# 1  False  False  False  False   False   False  False  False  False  False
# 2  False  False  False  False    True    True  False  False  False  False
# 3  False  False  False  False    True    True  False  False  False  False
# 4  False  False  False  False   False   False  False  False  False  False
#
#    Season   City  Sport  Event  Medal
# 0   False  False  False  False   True
# 1   False  False  False  False   True
# 2   False  False  False  False   True
# 3   False  False  False  False  False
# 4   False  False  False  False   True

# %%
olympics.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
olympics.isnull().mean()
# Out:
# ID        0.000000
# Name      0.000000
# Sex       0.000000
# Age       0.034944
# Height    0.221938
# Weight    0.231912
# Team      0.000000
# NOC       0.000000
# Games     0.000000
# Year      0.000000
# Season    0.000000
# City      0.000000
# Sport     0.000000
# Event     0.000000
# Medal     0.853262
# dtype: float64

# %% [markdown]
# Existen atletas repetidos en nuestros datasets?

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
london = olympics.query('Games == "2012 Summer"')

# %%
london.head()
# Out:
#      ID                                     Name Sex   Age  Height  Weight  \
# 1     2                                 A Lamusi   M  23.0   170.0    60.0
# 98   34       Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 134  48                         Abdelhak Aatakni   M  24.0     NaN    64.0
# 164  67  Mariya Vasilyevna Abakumova (-Tarabina)   F  26.0   179.0    80.0
# 174  73                                Luc Abalo   M  27.0   182.0    86.0
#
#         Team  NOC        Games  Year  Season    City      Sport  \
# 1      China  CHN  2012 Summer  2012  Summer  London       Judo
# 98    France  FRA  2012 Summer  2012  Summer  London  Athletics
# 134  Morocco  MAR  2012 Summer  2012  Summer  London     Boxing
# 164   Russia  RUS  2012 Summer  2012  Summer  London  Athletics
# 174   France  FRA  2012 Summer  2012  Summer  London   Handball
#
#                                Event Medal
# 1       Judo Men's Extra-Lightweight   NaN
# ...

# %%
london['Name'].value_counts()
# Out:
# Name
# Flavius Koczi                     8
# Kristian James Thomas             8
# Kim Su-Myeon                      8
# Oleh Yuriyovych Verniaiev         8
# Koji Yamamuro                     8
#                                  ..
# Szabolcs Zubai                    1
# Shahar Zubari                     1
# Steven Zuber                      1
# Stuart Bithell                    1
# Yegor Vyacheslavovich Zubovich    1
# Name: count, Length: 10502, dtype: int64

# %%
london.query('Name == "Kim Su-Myeon"')
# Out:
#            ID          Name Sex   Age  Height  Weight         Team  NOC  \
# 119081  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119082  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119083  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119084  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119085  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119086  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119087  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
# 119088  60273  Kim Su-Myeon   M  25.0   165.0    57.0  South Korea  KOR
#
#               Games  Year  Season    City       Sport  \
# 119081  2012 Summer  2012  Summer  London  Gymnastics
# 119082  2012 Summer  2012  Summer  London  Gymnastics
# 119083  2012 Summer  2012  Summer  London  Gymnastics
# 119084  2012 Summer  2012  Summer  London  Gymnastics
# ...

# %%
olympics['City'].unique()
# Out:
# array(['Barcelona', 'London', 'Antwerpen', 'Paris', 'Calgary',
#        'Albertville', 'Lillehammer', 'Los Angeles', 'Salt Lake City',
#        'Helsinki', 'Lake Placid', 'Sydney', 'Atlanta', 'Stockholm',
#        'Sochi', 'Nagano', 'Torino', 'Beijing', 'Rio de Janeiro', 'Athina',
#        'Squaw Valley', 'Innsbruck', 'Sarajevo', 'Mexico City', 'Munich',
#        'Seoul', 'Berlin', 'Oslo', "Cortina d'Ampezzo", 'Melbourne',
#        'Roma', 'Amsterdam', 'Montreal', 'Moskva', 'Tokyo', 'Vancouver',
#        'Grenoble', 'Sapporo', 'Chamonix', 'St. Louis', 'Sankt Moritz',
#        'Garmisch-Partenkirchen'], dtype=object)

# %%
type(olympics["City"].unique())
# Out:
# numpy.ndarray

# %%
len(olympics["City"].unique())
# Out:
# 42

# %%
olympics["City"].unique().size
# Out:
# 42

# %%
olympics["City"].nunique()
# Out:
# 42

# %%
sorted(olympics["City"].unique())
# Out:
# ['Albertville',
#  'Amsterdam',
#  'Antwerpen',
#  'Athina',
#  'Atlanta',
#  'Barcelona',
#  'Beijing',
#  'Berlin',
#  'Calgary',
#  'Chamonix',
#  "Cortina d'Ampezzo",
#  'Garmisch-Partenkirchen',
#  'Grenoble',
#  'Helsinki',
#  'Innsbruck',
#  'Lake Placid',
#  'Lillehammer',
#  'London',
#  'Los Angeles',
#  'Melbourne',
#  'Mexico City',
#  'Montreal',
#  'Moskva',
#  'Munich',
#  'Nagano',
#  'Oslo',
#  'Paris',
#  'Rio de Janeiro',
#  'Roma',
#  'Salt Lake City',
#  'Sankt Moritz',
#  'Sapporo',
#  'Sarajevo',
#  'Seoul',
#  'Sochi',
#  'Squaw Valley',
#  'St. Louis',
#  'Stockholm',
#  'Sydney',
#  'Tokyo',
#  'Torino',
#  'Vancouver']

# %% [markdown]
# ¿Cuales son los años en los que tenemos información?

# %%
olympics['Year'].unique()
# Out:
# array([1992, 2012, 1920, 1900, 1988, 1994, 1932, 2002, 1952, 1980, 2000,
#        1996, 1912, 1924, 2014, 1948, 1998, 2006, 2008, 2016, 2004, 1960,
#        1964, 1984, 1968, 1972, 1936, 1956, 1928, 1976, 2010, 1906, 1904,
#        1908, 1896])

# %%
sorted(olympics['Year'].unique())
# Out:
# [np.int64(1896),
#  np.int64(1900),
#  np.int64(1904),
#  np.int64(1906),
#  np.int64(1908),
#  np.int64(1912),
#  np.int64(1920),
#  np.int64(1924),
#  np.int64(1928),
#  np.int64(1932),
#  np.int64(1936),
#  np.int64(1948),
#  np.int64(1952),
#  np.int64(1956),
#  np.int64(1960),
#  np.int64(1964),
#  np.int64(1968),
#  np.int64(1972),
#  np.int64(1976),
#  np.int64(1980),
#  np.int64(1984),
#  np.int64(1988),
#  np.int64(1992),
#  np.int64(1994),
#  np.int64(1996),
#  np.int64(1998),
#  np.int64(2000),
#  np.int64(2002),
#  np.int64(2004),
#  np.int64(2006),
#  np.int64(2008),
#  np.int64(2010),
#  np.int64(2012),
#  np.int64(2014),
#  np.int64(2016)]

# %%
olympics['Year'].min()
# Out:
# np.int64(1896)

# %%
olympics['Year'].max()
# Out:
# np.int64(2016)

# %%
olympics['Year'].max() - olympics['Year'].min()
# Out:
# np.int64(120)

# %%
olympics['City'].min()
# Out:
# 'Albertville'

# %%
olympics['City'].max()
# Out:
# 'Vancouver'

# %% [markdown]
# ***Medidas de Centralidad***

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# Media

# %%
olympics['Age'].mean()
# Out:
# np.float64(25.556898357297374)

# %% [markdown]
# Mediana

# %%
olympics['Age'].median()
# Out:
# np.float64(24.0)

# %% [markdown]
# Moda

# %%
olympics['Age'].mode()
# Out:
# 0    23.0
# Name: Age, dtype: float64

# %%
olympics['Age'].value_counts()
# Out:
# Age
# 23.0    21875
# 24.0    21720
# 22.0    20814
# 25.0    19707
# 21.0    19164
#         ...
# 81.0        2
# 84.0        1
# 96.0        1
# 10.0        1
# 97.0        1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# Media o mediana?

# %%
import numpy

# %%
edades = numpy.array([10,15,16,17,18,18,18,19,20,21,22,23,24,27,29,30,40,50,100])

# %%
numpy.mean(edades)
# Out:
# np.float64(27.210526315789473)

# %%
numpy.median(edades)
# Out:
# np.float64(21.0)

# %% [markdown]
# La mediana no se altera, sin embargo la media aumento en 2.1

# %%
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics[['Age', 'Height','Weight']].mean()
# Out:
# Age        25.556898
# Height    175.338970
# Weight     70.702393
# dtype: float64

# %%
olympics[["Age", "Height", "Weight"]].median()
# Out:
# Age        24.0
# Height    175.0
# Weight     70.0
# dtype: float64

# %%
olympics[["Age", "Height", "Weight"]].mode()
# Out:
#     Age  Height  Weight
# 0  23.0   180.0    70.0

# %% [markdown]
# Desviación estándar
#
#
# ![](attachment:image.png)

# %%
olympics['Age'].std()
# Out:
# np.float64(6.393560847035813)

# %% [markdown]
# Varianza

# %%
olympics["Age"].var()
# Out:
# np.float64(40.87762030474931)

# %%
olympics["Age"].std() ** 2
# Out:
# np.float64(40.8776203047493)

# %% [markdown]
# Describe

# %%
olympics.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
olympics[['Age','Height','Weight']].describe()
# Out:
#                  Age         Height         Weight
# count  261642.000000  210945.000000  208241.000000
# mean       25.556898     175.338970      70.702393
# std         6.393561      10.518462      14.348020
# min        10.000000     127.000000      25.000000
# 25%        21.000000     168.000000      60.000000
# 50%        24.000000     175.000000      70.000000
# 75%        28.000000     183.000000      79.000000
# max        97.000000     226.000000     214.000000

# %%
olympics[['Age', 'Height', 'Weight']].describe(percentiles = [0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,])
# Out:
#                  Age         Height         Weight
# count  261642.000000  210945.000000  208241.000000
# mean       25.556898     175.338970      70.702393
# std         6.393561      10.518462      14.348020
# min        10.000000     127.000000      25.000000
# 10%        19.000000     162.000000      54.000000
# 20%        21.000000     167.000000      59.000000
# 30%        22.000000     170.000000      63.000000
# 40%        23.000000     173.000000      66.000000
# 50%        24.000000     175.000000      70.000000
# 60%        26.000000     178.000000      73.000000
# 70%        27.000000     181.000000      77.000000
# 80%        29.000000     184.000000      82.000000
# 90%        33.000000     188.000000      89.000000
# max        97.000000     226.000000     214.000000

# %% [markdown]
# Distribuciones
#
# Histogramas
#
# Distribucioón de la altura de los atletas

# %%
seaborn.histplot(olympics, x = 'Height', bins = 15)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
numpy.histogram(olympics['Height'].dropna(), bins=15 )
# Out:
# (array([   27,   188,   641,  3045,  8259, 29568, 50285, 42460, 47224,
#         18478,  8170,  2095,   362,   126,    17]),
#  array([127. , 133.6, 140.2, 146.8, 153.4, 160. , 166.6, 173.2, 179.8,
#         186.4, 193. , 199.6, 206.2, 212.8, 219.4, 226. ]))

# %% [markdown]
# Matplotlib y Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
olympics.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
olympics.plot(kind= 'hist', y='Height', bins= 15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.hist(olympics['Height'],bins = 15)
# Out:
# (array([2.7000e+01, 1.8800e+02, 6.4100e+02, 3.0450e+03, 8.2590e+03,
#         2.9568e+04, 5.0285e+04, 4.2460e+04, 4.7224e+04, 1.8478e+04,
#         8.1700e+03, 2.0950e+03, 3.6200e+02, 1.2600e+02, 1.7000e+01]),
#  array([127. , 133.6, 140.2, 146.8, 153.4, 160. , 166.6, 173.2, 179.8,
#         186.4, 193. , 199.6, 206.2, 212.8, 219.4, 226. ]),
#  <BarContainer object of 15 artists>)

# %%
sns.set()

# %%
plt.hist(olympics["Height"], bins=15)
# Out:
# (array([2.7000e+01, 1.8800e+02, 6.4100e+02, 3.0450e+03, 8.2590e+03,
#         2.9568e+04, 5.0285e+04, 4.2460e+04, 4.7224e+04, 1.8478e+04,
#         8.1700e+03, 2.0950e+03, 3.6200e+02, 1.2600e+02, 1.7000e+01]),
#  array([127. , 133.6, 140.2, 146.8, 153.4, 160. , 166.6, 173.2, 179.8,
#         186.4, 193. , 199.6, 206.2, 212.8, 219.4, 226. ]),
#  <BarContainer object of 15 artists>)

# %%
sns.reset_orig()

# %%
olympics.plot(kind="hist", y="Height",  bins= 15)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ¿Existen diferencias entre las distribuciones de deportes distintos?

# %%
olympics.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
olympics['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
basket_gym = olympics[olympics['Sport'].isin(['Basketball','Gymnastics'])]

# %%
basket_gym.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight     Team  NOC  \
# 0    1                A Dijiang   M  24.0   180.0    80.0    China  CHN
# 41  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 43  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 0   1992 Summer  1992  Summer  Barcelona  Basketball
# 41  1948 Summer  1948  Summer     London  Gymnastics
# 42  1948 Summer  1948  Summer     London  Gymnastics
# 43  1948 Summer  1948  Summer     London  Gymnastics
# 44  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 0              Basketball Men's Basketball     NaN
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# ...

# %%
# %matplotlib inline
sns.histplot(basket_gym, x = 'Height', bins = 20 )
plt.show()

# %%
# %matplotlib inline
sns.histplot(basket_gym, x = 'Height', bins = 20 , hue = 'Sport')
plt.show()

# %% [markdown]
# Diagramas de cajas

# %%
olympics['Height'].describe()
# Out:
# count    210945.000000
# mean        175.338970
# std          10.518462
# min         127.000000
# 25%         168.000000
# 50%         175.000000
# 75%         183.000000
# max         226.000000
# Name: Height, dtype: float64

# %%
plt.figure(figsize= (2,8))
sns.boxplot(data = olympics, y = 'Height')
# Out:
# <Axes: ylabel='Height'>

# %%
plt.figure(figsize=(5,10 ))
sns.boxplot(data=basket_gym, y="Height", x = 'Sport')
# Out:
# <Axes: xlabel='Sport', ylabel='Height'>

# %% [markdown]
# Correlación de Pearson

# %%
basket_gym.head(2)
# Out:
#     ID                     Name Sex   Age  Height  Weight     Team  NOC  \
# 0    1                A Dijiang   M  24.0   180.0    80.0    China  CHN
# 41  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 0   1992 Summer  1992  Summer  Barcelona  Basketball
# 41  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 0              Basketball Men's Basketball     NaN
# 41  Gymnastics Men's Individual All-Around  Bronze

# %%
sns.scatterplot(data = basket_gym, x= 'Height', y= 'Weight')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
sns.scatterplot(data=basket_gym, x="Height", y="Age")
# Out:
# <Axes: xlabel='Height', ylabel='Age'>

# %% [markdown]
# Fórmula de correlación de Pearson
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %%
basket_gym.head(2)
# Out:
#     ID                     Name Sex   Age  Height  Weight     Team  NOC  \
# 0    1                A Dijiang   M  24.0   180.0    80.0    China  CHN
# 41  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           Games  Year  Season       City       Sport  \
# 0   1992 Summer  1992  Summer  Barcelona  Basketball
# 41  1948 Summer  1948  Summer     London  Gymnastics
#
#                                      Event   Medal
# 0              Basketball Men's Basketball     NaN
# 41  Gymnastics Men's Individual All-Around  Bronze

# %%
basket_gym[['Age','Height','Weight','Sport']].head()
# Out:
#      Age  Height  Weight       Sport
# 0   24.0   180.0    80.0  Basketball
# 41  28.0   175.0    64.0  Gymnastics
# 42  28.0   175.0    64.0  Gymnastics
# 43  28.0   175.0    64.0  Gymnastics
# 44  28.0   175.0    64.0  Gymnastics

# %%
basket_gym[['Age', 'Height', 'Weight']].corr()
# Out:
#              Age    Height    Weight
# Age     1.000000  0.458235  0.525656
# Height  0.458235  1.000000  0.936603
# Weight  0.525656  0.936603  1.000000

# %% [markdown]
# heatmap

# %%
sns.heatmap(basket_gym[['Age', 'Height', 'Weight']].corr(), annot= True)
# Out:
# <Axes: >

# %% [markdown]
# Pairplot

# %%
sns.pairplot(basket_gym[['Age', 'Height', 'Weight']])

# %%
sns.pairplot(basket_gym[["Age", "Height", "Weight"]], diag_kws = {'bins': 20})

# %%
sns.pairplot(basket_gym[["Age", "Height", "Weight","Sport"]], hue= 'Sport')

# %%
sns.pairplot(basket_gym[["Age", "Height", "Weight", "Sport"]], hue="Sport", diag_kind = 'hist',diag_kws ={'bins':20})

# %% [markdown]
# #### Ejercicio
#
# Forbes dataset: https://www.kaggle.com/datasets/parulpandey/forbes-highest-paid-athletes-19902019

# %%
forbes = pd.read_csv(r'..\datasets\03-analisis-exploratorio\forbes.csv')

# %%
forbes
# Out:
#                   Name Nationality  Current_Rank Previous_Year_Rank  \
# 0           Mike Tyson         USA             1                NaN
# 1       Buster Douglas         USA             2                NaN
# 2    Sugar Ray Leonard         USA             3                NaN
# 3         Ayrton Senna      Brazil             4                NaN
# 4          Alain Prost      France             5                NaN
# ..                 ...         ...           ...                ...
# 296      Stephen Curry         USA             6                  9
# 297       Kevin Durant         USA             7                 10
# 298        Tiger Woods         USA             8                 11
# 299       Kirk Cousins         USA             9               >100
# 300       Carson Wentz         USA            10               >100
#
#                  Sport  Year  Earnings
# 0               boxing  1990      28.6
# 1               boxing  1990      26.0
# ...

# %%
forbes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                301 non-null    object
#  1   Nationality         301 non-null    object
#  2   Current_Rank        301 non-null    int64
#  3   Previous_Year_Rank  277 non-null    object
#  4   Sport               301 non-null    object
#  5   Year                301 non-null    int64
#  6   Earnings            301 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 16.6+ KB

# %%
forbes.describe()
# Out:
#        Current_Rank         Year    Earnings
# count    301.000000   301.000000  301.000000
# mean       5.448505  2005.122924   45.516279
# std        2.850995     9.063563   33.525337
# min        1.000000  1990.000000    8.100000
# 25%        3.000000  1997.000000   24.000000
# 50%        5.000000  2005.000000   39.000000
# 75%        8.000000  2013.000000   59.400000
# max       10.000000  2020.000000  300.000000

# %%
forbes.query('Previous_Year_Rank.isnull()')
# Out:
#                    Name Nationality  Current_Rank Previous_Year_Rank  \
# 0            Mike Tyson         USA             1                NaN
# 1        Buster Douglas         USA             2                NaN
# 2     Sugar Ray Leonard         USA             3                NaN
# 3          Ayrton Senna      Brazil             4                NaN
# 4           Alain Prost      France             5                NaN
# 5         Jack Nicklaus         USA             6                NaN
# 6           Greg Norman   Australia             7                NaN
# 7        Michael Jordan         USA             8                NaN
# 8         Arnold Palmer         USA             8                NaN
# 9     Evander Holyfield         USA             8                NaN
# 80       Michael Jordan         USA             1                NaN
# 81   Michael Schumacher     Germany             2                NaN
# 82       Sergei Federov      Russia             3                NaN
# ...

# %%
forbes.query('Name == "Stephen Curry"')
# Out:
#               Name Nationality  Current_Rank Previous_Year_Rank       Sport  \
# 268  Stephen Curry         USA             8                NaN  Basketball
# 278  Stephen Curry         USA             8                  8  Basketball
# 289  Stephen Curry         USA             9                  8  Basketball
# 296  Stephen Curry         USA             6                  9  Basketball
#
#      Year  Earnings
# 268  2017      47.3
# 278  2018      76.9
# 289  2019      79.8
# 296  2020      74.4

# %%
forbes['Name'].value_counts()
# Out:
# Name
# Michael Jordan        19
# Tiger Woods           19
# Kobe Bryant           14
# Michael Schumacher    13
# LeBron James          13
#                       ..
# Canelo Alvarez         1
# Russell Wilson         1
# Aaron Rogers           1
# Kirk Cousins           1
# Carson Wentz           1
# Name: count, Length: 82, dtype: int64

# %%
forbes["Nationality"].value_counts()
# Out:
# Nationality
# USA                 206
# UK                   13
# Germany              13
# Switzerland          12
# Portugal             10
# Brazil                9
# Argentina             9
# Canada                6
# Italy                 4
# France                3
# Philippines           3
# Finland               3
# Australia             1
# Russia                1
# Austria               1
# Dominican             1
# Filipino              1
# Spain                 1
# Serbia                1
# Northern Ireland      1
# Ireland               1
# Mexico                1
# Name: count, dtype: int64

# %%
forbes.query('Nationality == "Argentina"')
# Out:
#              Name Nationality  Current_Rank Previous_Year_Rank   Sport  Year  \
# 210  Lionel Messi   Argentina            10                >20  soccer  2011
# 230  Lionel Messi   Argentina            10                 11  Soccer  2013
# 234  Lionel Messi   Argentina             4                 10  Soccer  2014
# 244  Lionel Messi   Argentina             4                  4  Soccer  2015
# 252  Lionel Messi   Argentina             2                  4  Soccer  2016
# 263  Lionel Messi   Argentina             3                  2  Soccer  2017
# 272  Lionel Messi   Argentina             2                  3  Soccer  2018
# 281  Lionel Messi   Argentina             1                  2  Soccer  2019
# 293  Lionel Messi   Argentina             3                  1  Soccer  2020
#
#      Earnings
# 210      32.3
# 230      41.3
# 234      64.7
# 244      73.8
# 252      81.4
# 263      80.0
# 272     111.0
# 281     127.0
# 293     104.0

# %%
forbes.value_counts(forbes['Sport'])
# Out:
# Sport
# Basketball                      54
# Boxing                          29
# basketball                      27
# Golf                            24
# Soccer                          22
# golf                            20
# Tennis                          18
# American Football               17
# boxing                          17
# soccer                          11
# Auto Racing                     10
# F1 racing                        8
# auto racing                      7
# F1 Motorsports                   5
# tennis                           5
# motorcycle gp                    4
# NASCAR                           3
# baseball                         3
# Baseball                         3
# NFL                              3
# Auto Racing (Nascar)             2
# Ice Hockey                       2
# Hockey                           1
# American Football / Baseball     1
# Auto racing                      1
# MMA                              1
# ...

# %%
forbes.query('Sport == "Soccer" ').sort_values(by = 'Earnings', ascending = False)
# Out:
#                   Name Nationality  Current_Rank Previous_Year_Rank   Sport  \
# 281       Lionel Messi   Argentina             1                  2  Soccer
# 272       Lionel Messi   Argentina             2                  3  Soccer
# 282  Cristiano Ronaldo    Portugal             2                  3  Soccer
# 273  Cristiano Ronaldo    Portugal             3                  1  Soccer
# 292  Cristiano Ronaldo    Portugal             2                  2  Soccer
# 283             Neymar      Brazil             3                  5  Soccer
# 293       Lionel Messi   Argentina             3                  1  Soccer
# 294             Neymar      Brazil             4                  3  Soccer
# 261  Cristiano Ronaldo    Portugal             1                  1  Soccer
# 275             Neymar      Brazil             5                 18  Soccer
# 251  Cristiano Ronaldo    Portugal             1                  3  Soccer
# ...

# %%
sns.countplot(data= forbes.query('Year == 2020'), x = 'Sport')
# Out:
# <Axes: xlabel='Sport', ylabel='count'>

# %%
plt.figure(figsize=(30,10))
sns.countplot(data = forbes, x = 'Sport' , color = 'blue')
# Out:
# <Axes: xlabel='Sport', ylabel='count'>

# %%
sns.histplot(data = forbes, x = 'Earnings', bins = 25)
# Out:
# <Axes: xlabel='Earnings', ylabel='Count'>

# %%
plt.figure(figsize=(5, 10))
sns.boxplot(data=forbes, y="Earnings", color="blue")
# Out:
# <Axes: ylabel='Earnings'>

# %%
forbes.query('Earnings > 200')
# Out:
#                  Name Nationality  Current_Rank Previous_Year_Rank   Sport  \
# 241  Floyd Mayweather         USA             1                  1  Boxing
# 271  Floyd Mayweather         USA             1               >100  Boxing
#
#      Year  Earnings
# 241  2015     300.0
# 271  2018     285.0

# %%
forbes.query("Earnings > 112")
# Out:
#                  Name  Nationality  Current_Rank Previous_Year_Rank   Sport  \
# 171       Tiger Woods          USA             1                  1    golf
# 241  Floyd Mayweather          USA             1                  1  Boxing
# 242    Manny Pacquiao  Philippines             2                 11  Boxing
# 271  Floyd Mayweather          USA             1               >100  Boxing
# 281      Lionel Messi    Argentina             1                  2  Soccer
#
#      Year  Earnings
# 171  2008     115.0
# 241  2015     300.0
# 242  2015     160.0
# 271  2018     285.0
# 281  2019     127.0
