# %% [markdown]
# ###Módulo 4
#
# Manipulación de dataframes
#
# Lectura de fuente de datos
#
#
# 120 años de olimpiadas: https://www.kaggle.com/datasets/heesoo37/120-years-of-olympic-history-athletes-and-results

# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt

olympics = pd.read_csv(r"..\datasets\03-analisis-exploratorio\olympics.csv")
olympics.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# Filtros
#
# Máscara de querys
#
# Atletas olimpicos peruanos

# %%
olympics['NOC'] == 'PER'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Name: NOC, Length: 271116, dtype: bool

# %%
olympics[olympics["NOC"] == "PER"]
# Out:
#             ID                          Name Sex   Age  Height  Weight  Team  \
# 1076       605  Fernando J. Abugattas Aboino   M  20.0   190.0    80.0  Peru
# 1077       606      Roberto Abugattas Aboino   M  21.0   182.0    77.0  Peru
# 1078       606      Roberto Abugattas Aboino   M  25.0   182.0    77.0  Peru
# 1166       649    Fernando Acevedo Portugues   M  22.0   175.0    65.0  Peru
# 1167       649    Fernando Acevedo Portugues   M  26.0   175.0    65.0  Peru
# ...        ...                           ...  ..   ...     ...     ...   ...
# 267568  133860    Miguel Zambrano de la Cruz   M  28.0   182.0   148.0  Peru
# 267640  133894    Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0  Peru
# 267641  133894    Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0  Peru
# 268048  134100                 Ramn Zavaleta   M  24.0   181.0    72.0  Peru
# 268270  134227  Carlos Erick Zegarra Presser   M  23.0   202.0   165.0  Peru
#
# ...

# %%
olympics.query('NOC == "PER"')
# Out:
#             ID                          Name Sex   Age  Height  Weight  Team  \
# 1076       605  Fernando J. Abugattas Aboino   M  20.0   190.0    80.0  Peru
# 1077       606      Roberto Abugattas Aboino   M  21.0   182.0    77.0  Peru
# 1078       606      Roberto Abugattas Aboino   M  25.0   182.0    77.0  Peru
# 1166       649    Fernando Acevedo Portugues   M  22.0   175.0    65.0  Peru
# 1167       649    Fernando Acevedo Portugues   M  26.0   175.0    65.0  Peru
# ...        ...                           ...  ..   ...     ...     ...   ...
# 267568  133860    Miguel Zambrano de la Cruz   M  28.0   182.0   148.0  Peru
# 267640  133894    Yulissa Noelia Zamudio Orl   F  20.0   185.0    75.0  Peru
# 267641  133894    Yulissa Noelia Zamudio Orl   F  24.0   185.0    75.0  Peru
# 268048  134100                 Ramn Zavaleta   M  24.0   181.0    72.0  Peru
# 268270  134227  Carlos Erick Zegarra Presser   M  23.0   202.0   165.0  Peru
#
# ...

# %%
olympics.query('NOC == "PER" or NOC == "ARG"')
# Out:
#             ID                      Name Sex   Age  Height  Weight       Team  \
# 165         68          Pablo Martn Abal   M  23.0   178.0    76.0  Argentina
# 166         68          Pablo Martn Abal   M  23.0   178.0    76.0  Argentina
# 176         74          Mara Laura Abalo   F  30.0   182.0    73.0  Argentina
# 714        407         Ral Daniel Abella   M  26.0     NaN     NaN  Argentina
# 715        407         Ral Daniel Abella   M  26.0     NaN     NaN  Argentina
# ...        ...                       ...  ..   ...     ...     ...        ...
# 270998  135513           Federico Zwanck   M  18.0     NaN     NaN  Argentina
# 270999  135513           Federico Zwanck   M  18.0     NaN     NaN  Argentina
# 271000  135513           Federico Zwanck   M  18.0     NaN     NaN  Argentina
# 271105  135565  Fernando scar Zylberberg   M  23.0   168.0    76.0  Argentina
# 271106  135565  Fernando scar Zylberberg   M  27.0   168.0    76.0  Argentina
#
# ...

# %%
olympics[olympics['NOC'].isin(['PER' , 'ARG'])]
# Out:
#             ID                      Name Sex   Age  Height  Weight       Team  \
# 165         68          Pablo Martn Abal   M  23.0   178.0    76.0  Argentina
# 166         68          Pablo Martn Abal   M  23.0   178.0    76.0  Argentina
# 176         74          Mara Laura Abalo   F  30.0   182.0    73.0  Argentina
# 714        407         Ral Daniel Abella   M  26.0     NaN     NaN  Argentina
# 715        407         Ral Daniel Abella   M  26.0     NaN     NaN  Argentina
# ...        ...                       ...  ..   ...     ...     ...        ...
# 270998  135513           Federico Zwanck   M  18.0     NaN     NaN  Argentina
# 270999  135513           Federico Zwanck   M  18.0     NaN     NaN  Argentina
# 271000  135513           Federico Zwanck   M  18.0     NaN     NaN  Argentina
# 271105  135565  Fernando scar Zylberberg   M  23.0   168.0    76.0  Argentina
# 271106  135565  Fernando scar Zylberberg   M  27.0   168.0    76.0  Argentina
#
# ...

# %% [markdown]
# Filtros Conjuntos
#
# Las medallas de Seúl '88

# %%
olympics.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
olympics['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
(olympics['NOC'] == 'PER') & (olympics['Sport'] == 'Voleyball' ) & (olympics['Year'] == '1988') & (olympics['Medal'] == 'Silver')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
olympics[(olympics["NOC"] == "PER") & 
         (olympics["Sport"] == "Volleyball") & 
         (olympics["Year"] == 1988) & 
         (olympics["Medal"] == "Silver")]
# Out:
#             ID                                             Name Sex   Age  \
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# 242031  121233                                   Gina Torrealva   F  26.0
# 246625  123484                  Cenaida Cebastiana Uribe Medina   F  22.0
#
# ...

# %%
olympics.query('NOC == "PER" & Sport == "Volleyball" & Year == 1988 & Medal == "Silver"')
# Out:
#             ID                                             Name Sex   Age  \
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# 242031  121233                                   Gina Torrealva   F  26.0
# 246625  123484                  Cenaida Cebastiana Uribe Medina   F  22.0
#
# ...

# %% [markdown]
# Usar paréntesis para evitar interpretaciones erróneas

# %%
olympics.query('(NOC == "PER") & (Sport == "Volleyball") & (Year == 1988) & (Medal == "Silver")')
# Out:
#             ID                                             Name Sex   Age  \
# 37847    19448                     Luisa Haydee Cervera Cevedon   F  24.0
# 51127    26272                           Alejandra de la Guerra   F  20.0
# 66098    33819                            Denisse Fajardo Garca   F  24.0
# 75122    38118                                  Miriam Gallardo   F  20.0
# 76249    38692                         Rosa Gisella Garca Rivas   F  24.0
# 94622    47883                             Sonia Isabel Heredia   F  24.0
# 98804    50004                          Katherine "Kathy" Horny   F  18.0
# 147339   73946                         Natalia Mara Mlaga Dibos   F  24.0
# 185611   93317  Gabriela Lourdes "Gaby" Prez del Solar Cuculiza   F  20.0
# 234999  117844                   Cecilia Roxana Tait Villacorta   F  26.0
# 242031  121233                                   Gina Torrealva   F  26.0
# 246625  123484                  Cenaida Cebastiana Uribe Medina   F  22.0
#
# ...

# %% [markdown]
# **Filtros con comparaciones**

# %%
olympics.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN

# %%
olympics[olympics['Age'] < 20].head(2)
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
#
#            Team  NOC        Games  Year  Season         City      Sport  \
# 26  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles  Athletics
# 27  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles  Athletics
#
#                                      Event Medal
# 26            Athletics Women's 100 metres   NaN
# 27  Athletics Women's 4 x 100 metres Relay   NaN

# %%
olympics[olympics['Weight'] > olympics['Height']]
# Out:
#           ID               Name Sex   Age  Height  Weight  Team  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              Games  Year  Season     City Sport                   Event Medal
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN

# %%
olympics.query('Weight > Height')
# Out:
#           ID               Name Sex   Age  Height  Weight  Team  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              Games  Year  Season     City Sport                   Event Medal
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN

# %% [markdown]
# **FIltros con listas**

# %%
olympics['Sport'].unique()
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Speed Skating',
#        'Cross Country Skiing', 'Athletics', 'Ice Hockey', 'Swimming',
#        'Badminton', 'Sailing', 'Biathlon', 'Gymnastics',
#        'Art Competitions', 'Alpine Skiing', 'Handball', 'Weightlifting',
#        'Wrestling', 'Luge', 'Water Polo', 'Hockey', 'Rowing', 'Bobsleigh',
#        'Fencing', 'Equestrianism', 'Shooting', 'Boxing', 'Taekwondo',
#        'Cycling', 'Diving', 'Canoeing', 'Tennis', 'Modern Pentathlon',
#        'Figure Skating', 'Golf', 'Softball', 'Archery', 'Volleyball',
#        'Synchronized Swimming', 'Table Tennis', 'Nordic Combined',
#        'Baseball', 'Rhythmic Gymnastics', 'Freestyle Skiing',
#        'Rugby Sevens', 'Trampolining', 'Beach Volleyball', 'Triathlon',
#        'Ski Jumping', 'Curling', 'Snowboarding', 'Rugby',
#        'Short Track Speed Skating', 'Skeleton', 'Lacrosse', 'Polo',
#        'Cricket', 'Racquets', 'Motorboating', 'Military Ski Patrol',
# ...

# %%
deportes = ["Table Tennis", "Tennis"]

# %%
olympics[olympics['Sport'].isin(deportes)]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 184         82                Enrique Abaroa Martnez   M  26.0   183.0
# 498        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 499        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 500        277                    Shaimaa Abdul Aziz   F  27.0   160.0
# 582        334              Abubakar Sadiq Abdullahi   M  28.0     NaN
# ...        ...                                   ...  ..   ...     ...
# 270980  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
# 270986  135508              Vera Igorevna Zvonaryova   F  23.0   172.0
# 270987  135508              Vera Igorevna Zvonaryova   F  23.0   172.0
# 270988  135508              Vera Igorevna Zvonaryova   F  27.0   172.0
# 271020  135526                          Dniel Zwickl   M  27.0   178.0
#
#         Weight      Team  NOC        Games  Year  Season     City  \
# ...

# %%
olympics[olympics["Sport"].isin(deportes) & (olympics['City'] == 'Sydney')]
# Out:
#             ID                                  Name Sex   Age  Height  \
# 184         82                Enrique Abaroa Martnez   M  26.0   183.0
# 498        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 499        277                    Shaimaa Abdul Aziz   F  19.0   160.0
# 1457       812                     David Dixie Adams   M  30.0   188.0
# 2022      1116      Eldijana Dana Aganovi (-Bentsen)   F  28.0   173.0
# ...        ...                                   ...  ..   ...     ...
# 269911  135043                         Nenad Zimonji   M  24.0   190.0
# 270775  135417                 Fabiola Zuluaga Amado   F  21.0   171.0
# 270776  135417                 Fabiola Zuluaga Amado   F  21.0   171.0
# 270979  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
# 270980  135502  Nataliya Maratovna "Natasha" Zvereva   F  29.0   172.0
#
#         Weight                   Team  NOC        Games  Year  Season    City  \
# ...

# %% [markdown]
# **Filtros con valores Nulos**

# %%
olympics['Medal'].isnull()
# Out:
# 0          True
# 1          True
# 2          True
# 3         False
# 4          True
#           ...
# 271111     True
# 271112     True
# 271113     True
# 271114     True
# 271115     True
# Name: Medal, Length: 271116, dtype: bool

# %%
olympics[olympics["Medal"].isnull()]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 0             China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# Lo negamos con virgulilla

# %%
olympics[~olympics["Medal"].isnull()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %%
olympics[olympics["Medal"].notnull()]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 3            4                 Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 37          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 38          15                 Arvo Ossian Aaltonen   M  30.0     NaN     NaN
# 40          16             Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0
# 41          17              Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                                  ...  ..   ...     ...     ...
# 271078  135553  Galina Ivanovna Zybina (-Fyodorova)   F  25.0   168.0    80.0
# 271080  135553  Galina Ivanovna Zybina (-Fyodorova)   F  33.0   168.0    80.0
# 271082  135554                         Bogusaw Zych   M  28.0   182.0    82.0
# 271102  135563            Olesya Nikolayevna Zykina   F  19.0   171.0    64.0
# 271103  135563            Olesya Nikolayevna Zykina   F  23.0   171.0    64.0
#
# ...

# %% [markdown]
# **Filtros Negativos**

# %%
olympics[olympics["NOC"] == 'CHN']
# Out:
#             ID           Name Sex   Age  Height  Weight   Team  NOC  \
# 0            1      A Dijiang   M  24.0   180.0    80.0  China  CHN
# 1            2       A Lamusi   M  23.0   170.0    60.0  China  CHN
# 1072       602  Abudoureheman   M  22.0   182.0    75.0  China  CHN
# 2611      1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN
# 2612      1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN
# ...        ...            ...  ..   ...     ...     ...    ...  ...
# 270443  135272     Zou Wenzhi   M   NaN     NaN     NaN  China  CHN
# 270444  135273     Zou Yuchen   M  20.0   203.0   107.0  China  CHN
# 270445  135274   Zou Zhenxian   M  28.0   184.0    72.0  China  CHN
# 270559  135318       Zu Lijun   M  26.0   188.0    87.0  China  CHN
# 270822  135445        Zuo Yue   M  21.0   192.0    88.0  China  CHN
#
#               Games  Year  Season            City       Sport  \
# 0       1992 Summer  1992  Summer       Barcelona  Basketball
# ...

# %%
olympics[~(olympics["NOC"] == "CHN")]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# ...

# %%
olympics[olympics["NOC"] != "CHN"]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# ...

# %% [markdown]
# #### Filtros con patrones
#
# Nadia Comaneci

# %%
ordena_NOC = olympics['NOC'].unique()
ordena_NOC.sort()
print(ordena_NOC)
# Out:
# ['AFG' 'AHO' 'ALB' 'ALG' 'AND' 'ANG' 'ANT' 'ANZ' 'ARG' 'ARM' 'ARU' 'ASA'
#  'AUS' 'AUT' 'AZE' 'BAH' 'BAN' 'BAR' 'BDI' 'BEL' 'BEN' 'BER' 'BHU' 'BIH'
#  'BIZ' 'BLR' 'BOH' 'BOL' 'BOT' 'BRA' 'BRN' 'BRU' 'BUL' 'BUR' 'CAF' 'CAM'
#  'CAN' 'CAY' 'CGO' 'CHA' 'CHI' 'CHN' 'CIV' 'CMR' 'COD' 'COK' 'COL' 'COM'
#  'CPV' 'CRC' 'CRO' 'CRT' 'CUB' 'CYP' 'CZE' 'DEN' 'DJI' 'DMA' 'DOM' 'ECU'
#  'EGY' 'ERI' 'ESA' 'ESP' 'EST' 'ETH' 'EUN' 'FIJ' 'FIN' 'FRA' 'FRG' 'FSM'
#  'GAB' 'GAM' 'GBR' 'GBS' 'GDR' 'GEO' 'GEQ' 'GER' 'GHA' 'GRE' 'GRN' 'GUA'
#  'GUI' 'GUM' 'GUY' 'HAI' 'HKG' 'HON' 'HUN' 'INA' 'IND' 'IOA' 'IRI' 'IRL'
#  'IRQ' 'ISL' 'ISR' 'ISV' 'ITA' 'IVB' 'JAM' 'JOR' 'JPN' 'KAZ' 'KEN' 'KGZ'
#  'KIR' 'KOR' 'KOS' 'KSA' 'KUW' 'LAO' 'LAT' 'LBA' 'LBR' 'LCA' 'LES' 'LIB'
#  'LIE' 'LTU' 'LUX' 'MAD' 'MAL' 'MAR' 'MAS' 'MAW' 'MDA' 'MDV' 'MEX' 'MGL'
#  'MHL' 'MKD' 'MLI' 'MLT' 'MNE' 'MON' 'MOZ' 'MRI' 'MTN' 'MYA' 'NAM' 'NBO'
#  'NCA' 'NED' 'NEP' 'NFL' 'NGR' 'NIG' 'NOR' 'NRU' 'NZL' 'OMA' 'PAK' 'PAN'
# ...

# %%
olympics_rou = olympics[olympics['NOC'] == 'ROU']
olympics_rou
# Out:
#             ID               Name Sex   Age  Height  Weight     Team  NOC  \
# 80          22      Andreea Aanei   F  22.0   170.0   125.0  Romania  ROU
# 876        506     Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU
# 877        506     Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU
# 878        506     Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU
# 879        506     Andrei Abraham   M  19.0     NaN     NaN  Romania  ROU
# ...        ...                ...  ..   ...     ...     ...      ...  ...
# 270142  135149         Ion Zltaru   M  24.0     NaN     NaN  Romania  ROU
# 270295  135214       tefan Zoller   M  21.0     NaN     NaN  Romania  ROU
# 270361  135242  Ileana Zrg-Raduly   F  17.0   176.0    71.0  Romania  ROU
# 270362  135242  Ileana Zrg-Raduly   F  21.0   176.0    71.0  Romania  ROU
# 270363  135242  Ileana Zrg-Raduly   F  25.0   176.0    71.0  Romania  ROU
#
#               Games  Year  Season            City          Sport  \
# ...

# %%
olympics_rou['Name'].unique()
# Out:
# array(['Andreea Aanei', 'Andrei Abraham', 'Elisabeta Abrudeanu', ...,
#        'Ion Zltaru', 'tefan Zoller', 'Ileana Zrg-Raduly'], dtype=object)

# %%
olympics_rou['Name']
# Out:
# 80            Andreea Aanei
# 876          Andrei Abraham
# 877          Andrei Abraham
# 878          Andrei Abraham
# 879          Andrei Abraham
#                 ...
# 270142           Ion Zltaru
# 270295         tefan Zoller
# 270361    Ileana Zrg-Raduly
# 270362    Ileana Zrg-Raduly
# 270363    Ileana Zrg-Raduly
# Name: Name, Length: 4405, dtype: object

# %%
nombre = 'Nadia Comaneci'
nombre.startswith('Nadia')
# Out:
# True

# %%
nombre.endswith('ci')
# Out:
# True

# %%
olympics_rou[olympics_rou['Name'].str.startswith('Nadia')]
# Out:
#           ID                           Name Sex   Age  Height  Weight  \
# 43773  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43774  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43775  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43776  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43777  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43778  22570  Nadia Elena Comneci (-Conner)   F  14.0   162.0    45.0
# 43779  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43780  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43781  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43782  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43783  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
# 43784  22570  Nadia Elena Comneci (-Conner)   F  18.0   162.0    45.0
#
# ...

# %% [markdown]
# Ejercicios
#
# Usain Bolt y Michael Phelps

# %%
olympics[olympics['Name'].str.startswith('Usain')]
# Out:
#           ID                Name Sex   Age  Height  Weight     Team  NOC  \
# 24876  13029  Usain St. Leo Bolt   M  17.0   196.0    95.0  Jamaica  JAM
# 24877  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24878  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24879  13029  Usain St. Leo Bolt   M  21.0   196.0    95.0  Jamaica  JAM
# 24880  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24881  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24882  13029  Usain St. Leo Bolt   M  25.0   196.0    95.0  Jamaica  JAM
# 24883  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
# 24884  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
# 24885  13029  Usain St. Leo Bolt   M  29.0   196.0    95.0  Jamaica  JAM
#
#              Games  Year  Season            City      Sport  \
# 24876  2004 Summer  2004  Summer          Athina  Athletics
# ...

# %%
olympics[olympics['Name'].str.startswith('Michael')]
# Out:
#             ID                                    Name Sex   Age  Height  \
# 739        423                 Michael Brent Abernathy   M  22.0   182.0
# 1366       772                  Michael B. "Mike" Adam   M  24.0   175.0
# 2134      1185  Michael George Raymond "Mike" Agostini   M  21.0   171.0
# 2135      1185  Michael George Raymond "Mike" Agostini   M  21.0   171.0
# 2271      1258                         Michael Aguilar   M  24.0   178.0
# ...        ...                                     ...  ..   ...     ...
# 268573  134363                          Michael Zerbes   M  24.0   195.0
# 268574  134363                          Michael Zerbes   M  24.0   195.0
# 269896  135035                      Michael Zimmermann   M  29.0   174.0
# 269897  135035                      Michael Zimmermann   M  29.0   174.0
# 270522  135299                         Michaela Zrstov   F  25.0   186.0
#
#         Weight                 Team  NOC        Games  Year  Season  \
# ...

# %%
olympics[olympics['Name'].str.endswith('Phelps')]
# Out:
#            ID                      Name Sex   Age  Height  Weight  \
# 187877  94403         Brian Eric Phelps   M  16.0   168.0    67.0
# 187878  94403         Brian Eric Phelps   M  20.0   168.0    67.0
# 187885  94405      Mason Elliott Phelps   M  18.0     NaN     NaN
# 187886  94405      Mason Elliott Phelps   M  18.0     NaN     NaN
# 187917  94407  Harold Roy "Pete" Phelps   M  21.0   181.0    65.0
# 187918  94408              Peter Phelps   M  19.0     NaN     NaN
# 187926  94410    Richard Charles Phelps   M  26.0   196.0    92.0
# 187927  94411      Robert Edward Phelps   M  21.0     NaN     NaN
#
#                               Team  NOC        Games  Year  Season       City  \
# 187877               Great Britain  GBR  1960 Summer  1960  Summer       Roma
# 187878               Great Britain  GBR  1964 Summer  1964  Summer      Tokyo
# 187885               United States  USA  1904 Summer  1904  Summer  St. Louis
# ...

# %%
olympics[olympics["Name"].str.contains("Phelps")]
# Out:
#             ID                                   Name Sex   Age  Height  \
# 77897    39554              John Phelps "Jack" George   M  26.0     NaN
# 77898    39554              John Phelps "Jack" George   M  26.0     NaN
# 187877   94403                      Brian Eric Phelps   M  16.0   168.0
# 187878   94403                      Brian Eric Phelps   M  20.0   168.0
# 187879   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# ...        ...                                    ...  ..   ...     ...
# 206560  103687   Monica Kathleen Rutherford (-Phelps)   F  20.0   160.0
# 206561  103687   Monica Kathleen Rutherford (-Phelps)   F  20.0   160.0
# 206562  103687   Monica Kathleen Rutherford (-Phelps)   F  20.0   160.0
# 206563  103687   Monica Kathleen Rutherford (-Phelps)   F  20.0   160.0
# 206564  103687   Monica Kathleen Rutherford (-Phelps)   F  20.0   160.0
#
#         Weight           Team  NOC        Games  Year  Season     City  \
# ...

# %%
olympics[olympics["Name"].str.contains("Phelps") & (olympics['NOC'] == 'USA')]
# Out:
#             ID                                   Name Sex   Age  Height  \
# 187879   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# 187880   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# 187881   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# 187882   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# 187883   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# 187884   94404  Jaycie Lynn Phelps (-McClure, -Marus)   F  16.0     NaN
# 187885   94405                   Mason Elliott Phelps   M  18.0     NaN
# 187886   94405                   Mason Elliott Phelps   M  18.0     NaN
# 187887   94406                Michael Fred Phelps, II   M  15.0   193.0
# 187888   94406                Michael Fred Phelps, II   M  19.0   193.0
# 187889   94406                Michael Fred Phelps, II   M  19.0   193.0
# 187890   94406                Michael Fred Phelps, II   M  19.0   193.0
# ...

# %%
olympics[olympics["Name"].str.contains("Phelps") & (olympics["NOC"] == "USA") & (olympics['Sport'] == 'Swimming')]
# Out:
#            ID                     Name Sex   Age  Height  Weight  \
# 187887  94406  Michael Fred Phelps, II   M  15.0   193.0    91.0
# 187888  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187889  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187890  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187891  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187892  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187893  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187894  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187895  94406  Michael Fred Phelps, II   M  19.0   193.0    91.0
# 187896  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187897  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187898  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# 187899  94406  Michael Fred Phelps, II   M  23.0   193.0    91.0
# ...

# %%
olympicsPhelps = olympics[
    olympics["Name"].str.contains("Phelps")
    & (olympics["NOC"] == "USA")
    & (olympics["Sport"] == "Swimming")
]

# %% [markdown]
# ***Ejercicio con Phelps***
#
# Quienes le ganaron?

# %%
olympicsPhelps = olympicsPhelps.query("Medal != 'Gold'")

# %%
olympicsPhelps['EventGame'] = olympicsPhelps['Games'] + ' - ' + olympicsPhelps['Event']

# %%
olympics["EventGame"] = olympics["Games"] + " - " + olympics["Event"]

# %%
eventPhelps = list(olympicsPhelps['EventGame'])
eventPhelps
# Out:
# ["2000 Summer - Swimming Men's 200 metres Butterfly",
#  "2004 Summer - Swimming Men's 200 metres Freestyle",
#  "2004 Summer - Swimming Men's 4 x 100 metres Freestyle Relay",
#  "2012 Summer - Swimming Men's 4 x 100 metres Freestyle Relay",
#  "2012 Summer - Swimming Men's 200 metres Butterfly",
#  "2012 Summer - Swimming Men's 400 metres Individual Medley",
#  "2016 Summer - Swimming Men's 100 metres Butterfly"]

# %%
olympics.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#                                     EventGame
# 0   1992 Summer - Basketball Men's Basketball
# 1  2012 Summer - Judo Men's Extra-Lightweight

# %%
olympics[olympics['EventGame'].isin(eventPhelps) & (olympics['Medal'] == 'Gold')]
# Out:
#             ID                                   Name Sex   Age  Height  \
# 2111      1173                          Yannick Agnel   M  20.0   202.0
# 20241    10674        Alain Andr Louis Edmond Bernard   M  29.0   196.0
# 68360    34914                           Lyndon Ferns   M  20.0   187.0
# 79554    40403  Fabien Pierre Aurlien Dominique Gilot   M  28.0   193.0
# 134048   67496              Chad Guy Bertrand le Clos   M  20.0   190.0
# 135680   68271                          Clment Lefert   M  24.0   185.0
# 137501   69117                 Amaury Raymond Leveaux   M  26.0   202.0
# 141436   70965                     Ryan Steven Lochte   M  27.0   188.0
# 147417   73989            Thomas Andrew "Tom" Malchow   M  24.0   198.0
# 169198   85056                          Ryk Neethling   M  26.0   196.0
# 213783  107355                   Roland Mark Schoeman   M  24.0   190.0
# 213955  107436                 Joseph Isaac Schooling   M  21.0   184.0
# ...

# %% [markdown]
# Index, loc, iloc

# %%
olympics.loc[0]
# Out:
# ID                                                   1
# Name                                         A Dijiang
# Sex                                                  M
# Age                                               24.0
# Height                                           180.0
# Weight                                            80.0
# Team                                             China
# NOC                                                CHN
# Games                                      1992 Summer
# Year                                              1992
# Season                                          Summer
# City                                         Barcelona
# Sport                                       Basketball
# Event                      Basketball Men's Basketball
# Medal                                              NaN
# EventGame    1992 Summer - Basketball Men's Basketball
# Name: 0, dtype: object

# %%
olympics.loc[[0,1]]
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#                                     EventGame
# 0   1992 Summer - Basketball Men's Basketball
# 1  2012 Summer - Judo Men's Extra-Lightweight

# %%
olympics.loc[20:25]
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 20   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 21   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 23   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 24   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 25   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 20  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 21  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 23  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 24  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 25  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
# ...

# %%
olympics.iloc[20:25]
# Out:
#     ID          Name Sex   Age  Height  Weight           Team  NOC  \
# 20   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 21   7  John Aalberg   M  31.0   183.0    72.0  United States  USA
# 22   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 23   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
# 24   7  John Aalberg   M  33.0   183.0    72.0  United States  USA
#
#           Games  Year  Season         City                 Sport  \
# 20  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 21  1992 Winter  1992  Winter  Albertville  Cross Country Skiing
# 22  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 23  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
# 24  1994 Winter  1994  Winter  Lillehammer  Cross Country Skiing
#
#                                                 Event Medal  \
# 20  Cross Country Skiing Men's 10/15 kilometres Pu...   NaN
# ...

# %%
#olympics = olympics.set_index('ID')

# %%
#olympics.head(10)

# %%
olympics.loc[5]
# Out:
# ID                                                          5
# Name                                 Christine Jacoba Aaftink
# Sex                                                         F
# Age                                                      21.0
# Height                                                  185.0
# Weight                                                   82.0
# Team                                              Netherlands
# NOC                                                       NED
# Games                                             1988 Winter
# Year                                                     1988
# Season                                                 Winter
# City                                                  Calgary
# Sport                                           Speed Skating
# Event                      Speed Skating Women's 1,000 metres
# Medal                                                     NaN
# ...

# %%
olympics.iloc[5]
# Out:
# ID                                                          5
# Name                                 Christine Jacoba Aaftink
# Sex                                                         F
# Age                                                      21.0
# Height                                                  185.0
# Weight                                                   82.0
# Team                                              Netherlands
# NOC                                                       NED
# Games                                             1988 Winter
# Year                                                     1988
# Season                                                 Winter
# City                                                  Calgary
# Sport                                           Speed Skating
# Event                      Speed Skating Women's 1,000 metres
# Medal                                                     NaN
# ...

# %% [markdown]
# Seleccionar Columnas

# %%
olympics[['Name', 'Sport','Games']].head()
# Out:
#                        Name          Sport        Games
# 0                 A Dijiang     Basketball  1992 Summer
# 1                  A Lamusi           Judo  2012 Summer
# 2       Gunnar Nielsen Aaby       Football  1920 Summer
# 3      Edgar Lindenau Aabye     Tug-Of-War  1900 Summer
# 4  Christine Jacoba Aaftink  Speed Skating  1988 Winter

# %%
olympics.get(["Name", "Sport", "Games"]).head()
# Out:
#                        Name          Sport        Games
# 0                 A Dijiang     Basketball  1992 Summer
# 1                  A Lamusi           Judo  2012 Summer
# 2       Gunnar Nielsen Aaby       Football  1920 Summer
# 3      Edgar Lindenau Aabye     Tug-Of-War  1900 Summer
# 4  Christine Jacoba Aaftink  Speed Skating  1988 Winter

# %%
olympics.loc[5,['Name', 'Sex', 'Games']]
# Out:
# Name     Christine Jacoba Aaftink
# Sex                             F
# Games                 1988 Winter
# Name: 5, dtype: object

# %%
olympics.loc[5, 'Name': 'Team']
# Out:
# Name      Christine Jacoba Aaftink
# Sex                              F
# Age                           21.0
# Height                       185.0
# Weight                        82.0
# Team                   Netherlands
# Name: 5, dtype: object

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   ID         271116 non-null  int64
#  1   Name       271116 non-null  object
#  2   Sex        271116 non-null  object
#  3   Age        261642 non-null  float64
#  4   Height     210945 non-null  float64
#  5   Weight     208241 non-null  float64
#  6   Team       271116 non-null  object
#  7   NOC        271116 non-null  object
#  8   Games      271116 non-null  object
#  9   Year       271116 non-null  int64
#  10  Season     271116 non-null  object
#  11  City       271116 non-null  object
#  12  Sport      271116 non-null  object
#  13  Event      271116 non-null  object
#  14  Medal      39783 non-null   object
#  15  EventGame  271116 non-null  object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 33.1+ MB

# %%
olympics.dtypes
# Out:
# ID             int64
# Name          object
# Sex           object
# Age          float64
# Height       float64
# Weight       float64
# Team          object
# NOC           object
# Games         object
# Year           int64
# Season        object
# City          object
# Sport         object
# Event         object
# Medal         object
# EventGame     object
# dtype: object

# %%
olympics.select_dtypes('float').head
# Out:
# <bound method NDFrame.head of          Age  Height  Weight
# 0       24.0   180.0    80.0
# 1       23.0   170.0    60.0
# 2       24.0     NaN     NaN
# 3       34.0     NaN     NaN
# 4       21.0   185.0    82.0
# ...      ...     ...     ...
# 271111  29.0   179.0    89.0
# 271112  27.0   176.0    59.0
# 271113  27.0   176.0    59.0
# 271114  30.0   185.0    96.0
# 271115  34.0   185.0    96.0
#
# [271116 rows x 3 columns]>

# %%
olympics.select_dtypes('int').head()
# Out:
#    ID  Year
# 0   1  1992
# 1   2  2012
# 2   3  1920
# 3   4  1900
# 4   5  1988

# %%
olympics.select_dtypes('number').head()
# Out:
#    ID   Age  Height  Weight  Year
# 0   1  24.0   180.0    80.0  1992
# 1   2  23.0   170.0    60.0  2012
# 2   3  24.0     NaN     NaN  1920
# 3   4  34.0     NaN     NaN  1900
# 4   5  21.0   185.0    82.0  1988

# %%
olympics.select_dtypes(exclude = "number").head()
# Out:
#                        Name Sex            Team  NOC        Games  Season  \
# 0                 A Dijiang   M           China  CHN  1992 Summer  Summer
# 1                  A Lamusi   M           China  CHN  2012 Summer  Summer
# 2       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  Summer
# 3      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  Summer
# 4  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  Winter
#
#         City          Sport                             Event Medal  \
# 0  Barcelona     Basketball       Basketball Men's Basketball   NaN
# 1     London           Judo      Judo Men's Extra-Lightweight   NaN
# 2  Antwerpen       Football           Football Men's Football   NaN
# 3      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4    Calgary  Speed Skating  Speed Skating Women's 500 metres   NaN
#
#                                         EventGame
# 0       1992 Summer - Basketball Men's Basketball
# ...

# %%
olympics.select_dtypes(include ="object").head()
# Out:
#                        Name Sex            Team  NOC        Games  Season  \
# 0                 A Dijiang   M           China  CHN  1992 Summer  Summer
# 1                  A Lamusi   M           China  CHN  2012 Summer  Summer
# 2       Gunnar Nielsen Aaby   M         Denmark  DEN  1920 Summer  Summer
# 3      Edgar Lindenau Aabye   M  Denmark/Sweden  DEN  1900 Summer  Summer
# 4  Christine Jacoba Aaftink   F     Netherlands  NED  1988 Winter  Winter
#
#         City          Sport                             Event Medal  \
# 0  Barcelona     Basketball       Basketball Men's Basketball   NaN
# 1     London           Judo      Judo Men's Extra-Lightweight   NaN
# 2  Antwerpen       Football           Football Men's Football   NaN
# 3      Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4    Calgary  Speed Skating  Speed Skating Women's 500 metres   NaN
#
#                                         EventGame
# 0       1992 Summer - Basketball Men's Basketball
# ...

# %% [markdown]
# Cambiar nombres de columnas

# %%
olympics_2 = olympics.get(['Name','Sex','Age'])
olympics_2.head()
# Out:
#                        Name Sex   Age
# 0                 A Dijiang   M  24.0
# 1                  A Lamusi   M  23.0
# 2       Gunnar Nielsen Aaby   M  24.0
# 3      Edgar Lindenau Aabye   M  34.0
# 4  Christine Jacoba Aaftink   F  21.0

# %%
olympics_2.columns
# Out:
# Index(['Name', 'Sex', 'Age'], dtype='object')

# %%
olympics_2.columns = ['Nombe','Sexo', 'Edad']
olympics_2.head()
# Out:
#                       Nombe Sexo  Edad
# 0                 A Dijiang    M  24.0
# 1                  A Lamusi    M  23.0
# 2       Gunnar Nielsen Aaby    M  24.0
# 3      Edgar Lindenau Aabye    M  34.0
# 4  Christine Jacoba Aaftink    F  21.0

# %%
olympics_2 = olympics_2.rename(columns = {'Nombe' : 'Nombre'})
olympics_2.head()
# Out:
#                      Nombre Sexo  Edad
# 0                 A Dijiang    M  24.0
# 1                  A Lamusi    M  23.0
# 2       Gunnar Nielsen Aaby    M  24.0
# 3      Edgar Lindenau Aabye    M  34.0
# 4  Christine Jacoba Aaftink    F  21.0

# %%
[col.lower() for col in olympics_2.columns]
# Out:
# ['nombre', 'sexo', 'edad']

# %%
olympics_2.columns = [col.lower() for col in olympics_2.columns]
olympics_2.head()
# Out:
#                      nombre sexo  edad
# 0                 A Dijiang    M  24.0
# 1                  A Lamusi    M  23.0
# 2       Gunnar Nielsen Aaby    M  24.0
# 3      Edgar Lindenau Aabye    M  34.0
# 4  Christine Jacoba Aaftink    F  21.0

# %%
olympics_2.columns
# Out:
# Index(['nombre', 'sexo', 'edad'], dtype='object')

# %%
olympics_2.columns.str.upper()
# Out:
# Index(['NOMBRE', 'SEXO', 'EDAD'], dtype='object')

# %%
olympics_2.columns.str.capitalize()
# Out:
# Index(['Nombre', 'Sexo', 'Edad'], dtype='object')

# %%
olympics_2.columns = olympics_2.columns.str.upper()
olympics_2.head(2)
# Out:
#       NOMBRE SEXO  EDAD
# 0  A Dijiang    M  24.0
# 1   A Lamusi    M  23.0

# %%
olympics.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  NOC        Games  Year  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    Season       City       Sport                         Event Medal  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#                                     EventGame
# 0   1992 Summer - Basketball Men's Basketball
# 1  2012 Summer - Judo Men's Extra-Lightweight

# %%
olympics.columns = olympics.columns.str.upper()
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  SEASON       CITY          SPORT  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# Transformaciones entre columnas
#
# BMI = Body Mass Index
#
# Cálculo de Indice de Masa Muscular
#
# ![image.png](attachment:image.png)

# %%
olympics.head(2)
# Out:
#    ID       NAME SEX   AGE  HEIGHT  WEIGHT   TEAM  NOC        GAMES  YEAR  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer  1992
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer  2012
#
#    SEASON       CITY       SPORT                         EVENT MEDAL  \
# 0  Summer  Barcelona  Basketball   Basketball Men's Basketball   NaN
# 1  Summer     London        Judo  Judo Men's Extra-Lightweight   NaN
#
#                                     EVENTGAME
# 0   1992 Summer - Basketball Men's Basketball
# 1  2012 Summer - Judo Men's Extra-Lightweight

# %%
olympics['HEIGHT'] / 100
# Out:
# 0         1.80
# 1         1.70
# 2          NaN
# 3          NaN
# 4         1.85
#           ...
# 271111    1.79
# 271112    1.76
# 271113    1.76
# 271114    1.85
# 271115    1.85
# Name: HEIGHT, Length: 271116, dtype: float64

# %%
olympics["BMI"] = olympics["WEIGHT"] / ((olympics["HEIGHT"] / 100) ** 2)
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  SEASON       CITY          SPORT  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics['BMI'].describe()
# Out:
# count    206853.000000
# mean         22.784520
# std           2.912067
# min           8.360954
# 25%          20.957171
# 50%          22.530864
# 75%          24.212293
# max          63.901580
# Name: BMI, dtype: float64

# %%
olympics[olympics['BMI'] > 60]
# Out:
#           ID               NAME SEX   AGE  HEIGHT  WEIGHT  TEAM  NOC  \
# 23155  12177  Ricardo Blas, Jr.   M  21.0   183.0   214.0  Guam  GUM
# 23156  12177  Ricardo Blas, Jr.   M  25.0   183.0   214.0  Guam  GUM
#
#              GAMES  YEAR  SEASON     CITY SPORT                   EVENT MEDAL  \
# 23155  2008 Summer  2008  Summer  Beijing  Judo  Judo Men's Heavyweight   NaN
# 23156  2012 Summer  2012  Summer   London  Judo  Judo Men's Heavyweight   NaN
#
#                                   EVENTGAME       BMI
# 23155  2008 Summer - Judo Men's Heavyweight  63.90158
# 23156  2012 Summer - Judo Men's Heavyweight  63.90158

# %%
seaborn.histplot(olympics['BMI'], bins = 20)
# Out:
# <Axes: xlabel='BMI', ylabel='Count'>

# %% [markdown]
# Nombre completo del juego olímpico

# %%
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  SEASON       CITY          SPORT  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics['OLYMPIC'] = olympics['CITY'] + ' ' + olympics['YEAR'].astype(str)
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  SEASON       CITY          SPORT  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %% [markdown]
# Apply Map

# %%
olympics['SEX_NUMERIC'] = olympics['SEX'].map({'M' : 1, 'F': 0})
olympics.loc[:10,['SEX','SEX_NUMERIC']]
# Out:
#    SEX  SEX_NUMERIC
# 0    M            1
# 1    M            1
# 2    M            1
# 3    M            1
# 4    F            0
# 5    F            0
# 6    F            0
# 7    F            0
# 8    F            0
# 9    F            0
# 10   M            1

# %%
def esAdulto(EDAD):
    """
    This function determines if a person is an adult based on their age.

    Parameters:
    EDAD (int): The age of the person.

    Returns:
    int: 1 if the person is an adult (age >= 18), 0 otherwise.
    """
    if EDAD >= 18:
        return 1
    else:
        return 0

# %%
esAdulto(23)
# Out:
# 1

# %%
esAdulto(10)
# Out:
# 0

# %%
olympics['Adulto'] = olympics['AGE'].apply(esAdulto)
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  SEASON       CITY          SPORT  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
olympics.query('AGE < 19').head(10)
# Out:
#       ID                                       NAME SEX   AGE  HEIGHT  WEIGHT  \
# 26     8         Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27     8         Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 87    26               Agnes Erika Aanonsen (-Eyde)   F  17.0   169.0    65.0
# 203   96          Carlos Rodolfo Abaunza Balladares   M  18.0   168.0    60.0
# 204   97                     Carlos Alberto Abaunza   M  16.0   180.0    70.0
# 258  130                              Tural Abbasov   M  18.0   182.0    76.0
# 265  137                  Giordano Giulio Abbondati   M  15.0   175.0    64.0
# 295  159  Reem Wa'il Abdalazem Abdalazem El-Bossaty   F  15.0   167.0    60.0
# 296  159  Reem Wa'il Abdalazem Abdalazem El-Bossaty   F  15.0   167.0    60.0
# 317  170                      Maha Abdalsalam Gouda   F  18.0   172.0    61.0
#
#             TEAM  NOC        GAMES  YEAR  SEASON            CITY  \
# ...

# %%
olympics['HEIGHT_MTS'] = olympics['HEIGHT'].apply( lambda x: x/100)
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  ...       CITY          SPORT  \
# 0  CHN  1992 Summer  1992  ...  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  ...     London           Judo
# 2  DEN  1920 Summer  1920  ...  Antwerpen       Football
# 3  DEN  1900 Summer  1900  ...      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  ...    Calgary  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# ...

# %%
len("A Dijiang	")
# Out:
# 10

# %%
olympics['NAME_LENGTH'] = olympics['NAME'].apply(len)
olympics[['NAME','NAME_LENGTH']].head()
# Out:
#                        NAME  NAME_LENGTH
# 0                 A Dijiang            9
# 1                  A Lamusi            8
# 2       Gunnar Nielsen Aaby           19
# 3      Edgar Lindenau Aabye           20
# 4  Christine Jacoba Aaftink           24

# %%
olympics_float = olympics.select_dtypes('float')
olympics_float
# Out:
#          AGE  HEIGHT  WEIGHT        BMI  HEIGHT_MTS
# 0       24.0   180.0    80.0  24.691358        1.80
# 1       23.0   170.0    60.0  20.761246        1.70
# 2       24.0     NaN     NaN        NaN         NaN
# 3       34.0     NaN     NaN        NaN         NaN
# 4       21.0   185.0    82.0  23.959094        1.85
# ...      ...     ...     ...        ...         ...
# 271111  29.0   179.0    89.0  27.776911        1.79
# 271112  27.0   176.0    59.0  19.047004        1.76
# 271113  27.0   176.0    59.0  19.047004        1.76
# 271114  30.0   185.0    96.0  28.049671        1.85
# 271115  34.0   185.0    96.0  28.049671        1.85
#
# [271116 rows x 5 columns]

# %%
olympics_float.apply(max, axis = 0)
# Out:
# AGE            97.00000
# HEIGHT        226.00000
# WEIGHT        214.00000
# BMI            63.90158
# HEIGHT_MTS      2.26000
# dtype: float64

# %%
olympics_float.apply(max, axis = 1)
# Out:
# 0         180.0
# 1         170.0
# 2          24.0
# 3          34.0
# 4         185.0
#           ...
# 271111    179.0
# 271112    176.0
# 271113    176.0
# 271114    185.0
# 271115    185.0
# Length: 271116, dtype: float64

# %%
import numpy as np
olympics_float.apply(np.argmax)
# Out:
# AGE           257054
# HEIGHT        265040
# WEIGHT         23155
# BMI            23155
# HEIGHT_MTS    265040
# dtype: int64

# %%
olympics_float.loc[257054]
# Out:
# AGE           97.0
# HEIGHT         NaN
# WEIGHT         NaN
# BMI            NaN
# HEIGHT_MTS     NaN
# Name: 257054, dtype: float64

# %%
olympics_float.loc[265040]
# Out:
# AGE            20.000000
# HEIGHT        226.000000
# WEIGHT        141.000000
# BMI            27.605921
# HEIGHT_MTS      2.260000
# Name: 265040, dtype: float64

# %% [markdown]
# Ordenamientos

# %%
olympics_gold = olympics[olympics['MEDAL'] == 'Gold']
olympics_gold.head()
# Out:
#     ID                     NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        GAMES  YEAR  ...          SPORT  \
# 3   DEN  1900 Summer  1900  ...     Tug-Of-War
# 42  FIN  1948 Summer  1948  ...     Gymnastics
# 44  FIN  1948 Summer  1948  ...     Gymnastics
# 48  FIN  1948 Summer  1948  ...     Gymnastics
# 60  NOR  1992 Winter  1992  ...  Alpine Skiing
#
#                                EVENT MEDAL  \
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 42  Gymnastics Men's Team All-Around  Gold
# 44      Gymnastics Men's Horse Vault  Gold
# 48  Gymnastics Men's Pommelled Horse  Gold
# ...

# %%
olympics_gold.sort_values(by="AGE" , ascending=False).head(10)
# Out:
#             ID                                     NAME SEX   AGE  HEIGHT  \
# 105199   53238                          Charles Jacobus   M  64.0     NaN
# 233390  117046                        Oscar Gomer Swahn   M  64.0     NaN
# 104003   52626                     Isaac Lazarus Israls   M  63.0     NaN
# 261102  130662                  Robert W. Williams, Jr.   M  63.0     NaN
# 226374  113773             Galen Carter "G. C." Spencer   M  63.0   165.0
# 190952   95906  Lida Peyton "Eliza" Pollock (McMillen-)   F  63.0     NaN
# 159298   79961                   Joshua Kearney Millner   M  60.0     NaN
# 233386  117046                        Oscar Gomer Swahn   M  60.0     NaN
# 233387  117046                        Oscar Gomer Swahn   M  60.0     NaN
# 261675  130936                            Walter Winans   M  60.0     NaN
#
#         WEIGHT                TEAM  NOC        GAMES  YEAR  ...  \
# 105199     NaN       United States  USA  1904 Summer  1904  ...
# ...

# %%
olympics_gold.sort_values(by = ['AGE','NOC']).head(10)
# Out:
#             ID                                NAME SEX   AGE  HEIGHT  WEIGHT  \
# 73581    37398                          Fu Mingxia   F  13.0   160.0    48.0
# 268602  134381                         Klaus Zerta   M  13.0   165.0    48.0
# 119277   60384                          Kim Yun-Mi   F  13.0   160.0    48.0
# 27207    14142                       Hans Bourquin   M  13.0     NaN     NaN
# 52010    26731  Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 78544    39866        Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 200704  100797       Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 163440   82042        Sandra Anne Morgan (-Beavis)   F  14.0   167.0    67.0
# 147676   74100            Bernard Robert Malivoire   M  14.0     NaN     NaN
# 240012  120276                     Gunther Tiersch   M  14.0   160.0    45.0
#
#                  TEAM  NOC        GAMES  YEAR  ...                      SPORT  \
# ...

# %%
olympics_gold.sort_values(by=["AGE", "NOC"], ascending=[True, False]).head(10)
# Out:
#             ID                                 NAME SEX   AGE  HEIGHT  WEIGHT  \
# 52010    26731   Donna Elizabeth de Varona (-Pinto)   F  13.0   168.0    61.0
# 78544    39866         Marjorie Gestring (-Redlick)   F  13.0     NaN     NaN
# 200704  100797        Aileen Muriel Riggin (-Soule)   F  13.0   142.0     NaN
# 27207    14142                        Hans Bourquin   M  13.0     NaN     NaN
# 119277   60384                           Kim Yun-Mi   F  13.0   160.0    48.0
# 268602  134381                          Klaus Zerta   M  13.0   165.0    48.0
# 73581    37398                           Fu Mingxia   F  13.0   160.0    48.0
# 16849     9034            Amanda Ray Beard (-Brown)   F  14.0   173.0    59.0
# 150298   75395                 Barbara Ann Marshall   F  14.0   175.0    59.0
# 160920   80754  Dominique Helena Moceanu (-Canales)   F  14.0   139.0    34.0
#
#                  TEAM  NOC        GAMES  YEAR  ...                      SPORT  \
# ...

# %% [markdown]
# Cuentas y duplicados
#
# Países con más medallas olímpicas

# %%
olympics.query('NOC == "ARG" & MEDAL == "Silver"')
# Out:
#             ID                                    NAME SEX   AGE  HEIGHT  \
# 2618      1467        Mara Magdalena Aicega Amicarelli   F  26.0   165.0
# 5281      2988                      Matas Jess Almeyda   M  22.0   173.0
# 8292      4569        Mariela Andrea Antoniska Arrondo   F  25.0   170.0
# 9684      5307                             Ins Arrondo   F  22.0   167.0
# 11338     6201                     Roberto Fabin Ayala   M  23.0   177.0
# ...        ...                                     ...  ..   ...     ...
# 227011  114076             Mara Josefina "Jose" Sruoga   F  21.0   171.0
# 229046  115002                Ayeln Lara Stepnik Puche   F  24.0   169.0
# 236524  118586  Domingo Alberto Tarasconi (Tarascone-)   M  24.0     NaN
# 255105  127711                         Paola Vukojicic   F  26.0   164.0
# 267711  133933                  Javier Adelmar Zanetti   M  22.0   178.0
#
#         WEIGHT       TEAM  NOC        GAMES  YEAR  ...     SPORT  \
# ...

# %%
olympicsArg = olympics.query('NOC == "ARG" & MEDAL == "Silver"')

# %%
olympicsArg.drop_duplicates()
# Out:
#             ID                                    NAME SEX   AGE  HEIGHT  \
# 2618      1467        Mara Magdalena Aicega Amicarelli   F  26.0   165.0
# 5281      2988                      Matas Jess Almeyda   M  22.0   173.0
# 8292      4569        Mariela Andrea Antoniska Arrondo   F  25.0   170.0
# 9684      5307                             Ins Arrondo   F  22.0   167.0
# 11338     6201                     Roberto Fabin Ayala   M  23.0   177.0
# ...        ...                                     ...  ..   ...     ...
# 227011  114076             Mara Josefina "Jose" Sruoga   F  21.0   171.0
# 229046  115002                Ayeln Lara Stepnik Puche   F  24.0   169.0
# 236524  118586  Domingo Alberto Tarasconi (Tarascone-)   M  24.0     NaN
# 255105  127711                         Paola Vukojicic   F  26.0   164.0
# 267711  133933                  Javier Adelmar Zanetti   M  22.0   178.0
#
#         WEIGHT       TEAM  NOC        GAMES  YEAR  ...     SPORT  \
# ...

# %%
olympicsArg.drop_duplicates(subset = 'SPORT')
# Out:
#             ID                                      NAME SEX   AGE  HEIGHT  \
# 2618      1467          Mara Magdalena Aicega Amicarelli   F  26.0   165.0
# 5281      2988                        Matas Jess Almeyda   M  22.0   173.0
# 11521     6292                                Amado Azar   M  18.0   173.0
# 30629    15780                        Luis ngel Brunetto   M  22.0   186.0
# 33824    17428                        Hctor O. Calegaris   M  45.0   175.0
# 34375    17715        Jeannette Morven Campbell (-Peper)   F  20.0     NaN
# 52837    27132                      Juan Martn del Potro   M  27.0   198.0
# 53554    27477                           Alberto Demiddi   M  28.0   184.0
# 55184    28304  Carlos Enrique Daz Senz Valiente Bachman   M  31.0     NaN
# 162973   81836         Carlos Alberto Moratorio Telechea   M  34.0   170.0
# 216159  108504                         Humberto Selvetti   M  24.0   180.0
#
# ...

# %%
olympicsArg.drop_duplicates(subset = 'SPORT', keep = 'last')
# Out:
#             ID                                      NAME SEX   AGE  HEIGHT  \
# 34375    17715        Jeannette Morven Campbell (-Peper)   F  20.0     NaN
# 53554    27477                           Alberto Demiddi   M  28.0   184.0
# 55184    28304  Carlos Enrique Daz Senz Valiente Bachman   M  31.0     NaN
# 162973   81836         Carlos Alberto Moratorio Telechea   M  34.0   170.0
# 185260   93137                             Vctor Peralta   M  20.0     NaN
# 207296  104019                 Gabriela Beatriz Sabatini   F  18.0   175.0
# 216159  108504                         Humberto Selvetti   M  24.0   180.0
# 219488  110257     Enrique Conrado Sieburger Hadler, Sr.   M  50.0     NaN
# 220668  110829                 Noem Simonetto de Portela   F  22.0   171.0
# 255105  127711                           Paola Vukojicic   F  26.0   164.0
# 267711  133933                    Javier Adelmar Zanetti   M  22.0   178.0
#
# ...

# %% [markdown]
# dropna

# %%
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  ...          SPORT  \
# 0  CHN  1992 Summer  1992  ...     Basketball
# 1  CHN  2012 Summer  2012  ...           Judo
# 2  DEN  1920 Summer  1920  ...       Football
# 3  DEN  1900 Summer  1900  ...     Tug-Of-War
# 4  NED  1988 Winter  1988  ...  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
olympics.isnull().sum()
# Out:
# ID                  0
# NAME                0
# SEX                 0
# AGE              9474
# HEIGHT          60171
# WEIGHT          62875
# TEAM                0
# NOC                 0
# GAMES               0
# YEAR                0
# SEASON              0
# CITY                0
# SPORT               0
# EVENT               0
# MEDAL          231333
# EVENTGAME           0
# BMI             64263
# OLYMPIC             0
# SEX_NUMERIC         0
# Adulto              0
# HEIGHT_MTS      60171
# NAME_LENGTH         0
# dtype: int64

# %%
olympics.dropna(subset = 'MEDAL').head()
# Out:
#     ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        GAMES  YEAR  ...       SPORT  \
# 3   DEN  1900 Summer  1900  ...  Tug-Of-War
# 37  FIN  1920 Summer  1920  ...    Swimming
# 38  FIN  1920 Summer  1920  ...    Swimming
# 40  FIN  2014 Winter  2014  ...  Ice Hockey
# 41  FIN  1948 Summer  1948  ...  Gymnastics
#
#                                      EVENT   MEDAL  \
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# 38  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
olympics_medal = olympics.dropna(subset="MEDAL")

# %%
olympics_medal.isnull().sum()
# Out:
# ID                0
# NAME              0
# SEX               0
# AGE             732
# HEIGHT         8711
# WEIGHT         9327
# TEAM              0
# NOC               0
# GAMES             0
# YEAR              0
# SEASON            0
# CITY              0
# SPORT             0
# EVENT             0
# MEDAL             0
# EVENTGAME         0
# BMI            9587
# OLYMPIC           0
# SEX_NUMERIC       0
# Adulto            0
# HEIGHT_MTS     8711
# NAME_LENGTH       0
# dtype: int64

# %%
olympics_dropna = olympics.dropna()
olympics_dropna.isnull().sum()
# Out:
# ID             0
# NAME           0
# SEX            0
# AGE            0
# HEIGHT         0
# WEIGHT         0
# TEAM           0
# NOC            0
# GAMES          0
# YEAR           0
# SEASON         0
# CITY           0
# SPORT          0
# EVENT          0
# MEDAL          0
# EVENTGAME      0
# BMI            0
# OLYMPIC        0
# SEX_NUMERIC    0
# Adulto         0
# HEIGHT_MTS     0
# NAME_LENGTH    0
# dtype: int64

# %%
olympics_dropna.head()
# Out:
#     ID                      NAME SEX   AGE  HEIGHT  WEIGHT     TEAM  NOC  \
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0  Finland  FIN
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 42  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 44  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
# 48  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0  Finland  FIN
#
#           GAMES  YEAR  ...       SPORT  \
# 40  2014 Winter  2014  ...  Ice Hockey
# 41  1948 Summer  1948  ...  Gymnastics
# 42  1948 Summer  1948  ...  Gymnastics
# 44  1948 Summer  1948  ...  Gymnastics
# 48  1948 Summer  1948  ...  Gymnastics
#
#                                      EVENT   MEDAL  \
# 40             Ice Hockey Men's Ice Hockey  Bronze
# 41  Gymnastics Men's Individual All-Around  Bronze
# 42        Gymnastics Men's Team All-Around    Gold
# 44            Gymnastics Men's Horse Vault    Gold
# ...

# %%
olympics_all = olympics.dropna(how= 'all')

# %%
olympics_all.isnull().sum()
# Out:
# ID                  0
# NAME                0
# SEX                 0
# AGE              9474
# HEIGHT          60171
# WEIGHT          62875
# TEAM                0
# NOC                 0
# GAMES               0
# YEAR                0
# SEASON              0
# CITY                0
# SPORT               0
# EVENT               0
# MEDAL          231333
# EVENTGAME           0
# BMI             64263
# OLYMPIC             0
# SEX_NUMERIC         0
# Adulto              0
# HEIGHT_MTS      60171
# NAME_LENGTH         0
# dtype: int64

# %% [markdown]
# Group by

# %%
medals = olympics.dropna(subset = 'MEDAL')
medals.head(2)
# Out:
#     ID                  NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  NOC  \
# 3    4  Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden  DEN
# 37  15  Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland  FIN
#
#           GAMES  YEAR  ...       SPORT  \
# 3   1900 Summer  1900  ...  Tug-Of-War
# 37  1920 Summer  1920  ...    Swimming
#
#                                      EVENT   MEDAL  \
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
#
#                                             EVENTGAME BMI         OLYMPIC  \
# 3           1900 Summer - Tug-Of-War Men's Tug-Of-War NaN      Paris 1900
# 37  1920 Summer - Swimming Men's 200 metres Breast... NaN  Antwerpen 1920
#
#     SEX_NUMERIC Adulto  HEIGHT_MTS  NAME_LENGTH
# 3             1      1         NaN           20
# 37            1      1         NaN           20
#
# [2 rows x 22 columns]

# %%
medals.shape
# Out:
# (39783, 22)

# %%
medals= medals.drop_duplicates(subset = ['GAMES','EVENT'])
medals.shape
# Out:
# (6168, 22)

# %%
medals_subset = medals.head()
medals_subset
# Out:
#     ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#     NOC        GAMES  YEAR  ...       SPORT  \
# 3   DEN  1900 Summer  1900  ...  Tug-Of-War
# 37  FIN  1920 Summer  1920  ...    Swimming
# 38  FIN  1920 Summer  1920  ...    Swimming
# 40  FIN  2014 Winter  2014  ...  Ice Hockey
# 41  FIN  1948 Summer  1948  ...  Gymnastics
#
#                                      EVENT   MEDAL  \
# 3              Tug-Of-War Men's Tug-Of-War    Gold
# 37  Swimming Men's 200 metres Breaststroke  Bronze
# 38  Swimming Men's 400 metres Breaststroke  Bronze
# ...

# %%
medals_subset.groupby("NOC").count()
# Out:
#      ID  NAME  SEX  AGE  HEIGHT  WEIGHT  TEAM  GAMES  YEAR  SEASON  ...  \
# NOC                                                                 ...
# DEN   1     1    1    1       0       0     1      1     1       1  ...
# FIN   4     4    4    4       2       2     4      4     4       4  ...
#
#      SPORT  EVENT  MEDAL  EVENTGAME  BMI  OLYMPIC  SEX_NUMERIC  Adulto  \
# NOC
# DEN      1      1      1          1    0        1            1       1
# FIN      4      4      4          4    2        4            4       4
#
#      HEIGHT_MTS  NAME_LENGTH
# NOC
# DEN           0            1
# FIN           2            4
#
# [2 rows x 21 columns]

# %%
medals_subset.groupby('NOC').count()['MEDAL']
# Out:
# NOC
# DEN    1
# FIN    4
# Name: MEDAL, dtype: int64

# %%
medals_subset.groupby("NOC").count()[["MEDAL"]]
# Out:
#      MEDAL
# NOC
# DEN      1
# FIN      4

# %%
medals_subset.get(['NOC','MEDAL']).groupby("NOC").count()[["MEDAL"]]
# Out:
#      MEDAL
# NOC
# DEN      1
# FIN      4

# %%
medals_subset.get(['NOC', 'MEDAL']).groupby('NOC', as_index = False).count()
# Out:
#    NOC  MEDAL
# 0  DEN      1
# 1  FIN      4

# %%
medals_count = medals.get(["NOC", "MEDAL"]).groupby("NOC", as_index=False).count()
medals_count.head()
# Out:
#    NOC  MEDAL
# 0  AHO      1
# 1  ALG      4
# 2  ANZ      8
# 3  ARG     36
# 4  ARM      9

# %%
medals_count.sort_values('MEDAL', ascending=False).head(10)
# Out:
#      NOC  MEDAL
# 114  USA    988
# 112  URS    371
# 33   FRA    354
# 38   GER    334
# 35   GBR    326
# 54   ITA    290
# 97   SWE    240
# 90   RUS    192
# 78   NOR    190
# 16   CAN    162

# %% [markdown]
# group by agg

# %%
olympics_gb = olympics.get(['SPORT','AGE','HEIGHT','WEIGHT'])
olympics_gb.head()
# Out:
#            SPORT   AGE  HEIGHT  WEIGHT
# 0     Basketball  24.0   180.0    80.0
# 1           Judo  23.0   170.0    60.0
# 2       Football  24.0     NaN     NaN
# 3     Tug-Of-War  34.0     NaN     NaN
# 4  Speed Skating  21.0   185.0    82.0

# %%
olympics_gb = olympics_gb[olympics_gb['SPORT'].isin(['Basketball','Football'])]
olympics_gb.head(10)
# Out:
#           SPORT   AGE  HEIGHT  WEIGHT
# 0    Basketball  24.0   180.0    80.0
# 2      Football  24.0     NaN     NaN
# 105    Football  23.0   182.0    64.0
# 116    Football  28.0     NaN     NaN
# 157    Football  26.0   175.0    72.0
# 167  Basketball  19.0   185.0    72.0
# 178    Football  22.0   185.0    82.0
# 183    Football  22.0   190.0    77.0
# 198    Football  21.0   180.0    73.0
# 212    Football   NaN     NaN     NaN

# %%
olympics_gb.groupby('SPORT').count()
# Out:
#              AGE  HEIGHT  WEIGHT
# SPORT
# Basketball  4350    3881    3678
# Football    6370    4647    4533

# %%
olympics_gb.groupby("SPORT").mean()
# Out:
#                   AGE      HEIGHT     WEIGHT
# SPORT
# Basketball  25.324598  190.869879  85.777053
# Football    23.693250  175.402195  70.446834

# %%
olympics_gb.groupby("SPORT").min()
# Out:
#              AGE  HEIGHT  WEIGHT
# SPORT
# Basketball  16.0   161.0    50.0
# Football    15.0   140.0    28.0

# %%
olympics_gb.groupby("SPORT").agg({'AGE': 'mean',
                                  'HEIGHT': ['min','max']})
# Out:
#                   AGE HEIGHT
#                  mean    min    max
# SPORT
# Basketball  25.324598  161.0  226.0
# Football    23.693250  140.0  200.0

# %%
olympics_gb.groupby("SPORT").agg({"AGE": np.mean,
                                 "HEIGHT": [np.min, np.max]})
# Out:
# C:\Users\ooagu\AppData\Local\Temp\ipykernel_12304\2959265462.py:1: FutureWarning: The provided callable <function mean at 0x00000202B4606F20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   olympics_gb.groupby("SPORT").agg({"AGE": np.mean,
# C:\Users\ooagu\AppData\Local\Temp\ipykernel_12304\2959265462.py:1: FutureWarning: The provided callable <function min at 0x00000202B4606660> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   olympics_gb.groupby("SPORT").agg({"AGE": np.mean,
# ...

# %% [markdown]
# pivot table

# %%
medals.query('MEDAL == "Gold"')\
        .get(['NOC', 'MEDAL'])\
        .groupby('NOC', as_index = False)\
        .count()
# Out:
#     NOC  MEDAL
# 0   ALG      1
# 1   ANZ      2
# 2   ARG     10
# 3   ARM      1
# 4   AUS     51
# ..  ...    ...
# 79  USA    412
# 80  UZB      3
# 81  VIE      1
# 82  YUG     11
# 83  ZIM      1
#
# [84 rows x 2 columns]

# %%
medals.query('MEDAL == "Gold"')\
    .get(["NOC", "MEDAL"])\
    .groupby("NOC", as_index=False)\
    .count()\
    .sort_values('MEDAL', ascending=False)\
    .head(10)
# Out:
#     NOC  MEDAL
# 79  USA    412
# 77  URS    151
# 26  FRA    110
# 39  ITA    104
# 31  GER    103
# 28  GBR     93
# 53  NOR     81
# 66  SWE     66
# 61  RUS     60
# 33  HUN     54

# %%
medals.get(["NOC", "MEDAL","EVENT"])\
    .groupby(["NOC","MEDAL"], as_index=False)\
    .count()
# Out:
#      NOC   MEDAL  EVENT
# 0    AHO  Silver      1
# 1    ALG  Bronze      2
# 2    ALG    Gold      1
# 3    ALG  Silver      1
# 4    ANZ  Bronze      3
# ..   ...     ...    ...
# 281  YUG  Bronze      7
# 282  YUG    Gold     11
# 283  YUG  Silver      8
# 284  ZIM    Gold      1
# 285  ZIM  Silver      1
#
# [286 rows x 3 columns]

# %%
medals.get(['NOC','MEDAL','EVENT']).pivot_table(index = 'NOC', columns = 'MEDAL', aggfunc = 'count')
# Out:
#        EVENT
# MEDAL Bronze  Gold Silver
# NOC
# AHO      NaN   NaN    1.0
# ALG      2.0   1.0    1.0
# ANZ      3.0   2.0    3.0
# ARG     13.0  10.0   13.0
# ARM      5.0   1.0    3.0
# ..       ...   ...    ...
# VEN      5.0   NaN    NaN
# VIE      NaN   1.0    2.0
# WIF      1.0   NaN    NaN
# YUG      7.0  11.0    8.0
# ZIM      NaN   1.0    1.0
#
# [121 rows x 3 columns]

# %%
medals_pivot = medals.get(['NOC','MEDAL','EVENT']).pivot_table(index = 'NOC', columns = 'MEDAL', aggfunc = 'count', fill_value = 0)
medals_pivot
# Out:
#        EVENT
# MEDAL Bronze Gold Silver
# NOC
# AHO        0    0      1
# ALG        2    1      1
# ANZ        3    2      3
# ARG       13   10     13
# ARM        5    1      3
# ..       ...  ...    ...
# VEN        5    0      0
# VIE        0    1      2
# WIF        1    0      0
# YUG        7   11      8
# ZIM        0    1      1
#
# [121 rows x 3 columns]

# %%
medals_pivot.columns
# Out:
# MultiIndex([('EVENT', 'Bronze'),
#             ('EVENT',   'Gold'),
#             ('EVENT', 'Silver')],
#            names=[None, 'MEDAL'])

# %%
medals_pivot.columns = ['Bronze','Gold','Silver']
medals_pivot
# Out:
#      Bronze  Gold  Silver
# NOC
# AHO       0     0       1
# ALG       2     1       1
# ANZ       3     2       3
# ARG      13    10      13
# ARM       5     1       3
# ..      ...   ...     ...
# VEN       5     0       0
# VIE       0     1       2
# WIF       1     0       0
# YUG       7    11       8
# ZIM       0     1       1
#
# [121 rows x 3 columns]

# %%
medals_pivot = medals_pivot[['Gold','Silver','Bronze']]
medals_pivot
# Out:
#      Gold  Silver  Bronze
# NOC
# AHO     0       1       0
# ALG     1       1       2
# ANZ     2       3       3
# ARG    10      13      13
# ARM     1       3       5
# ..    ...     ...     ...
# VEN     0       0       5
# VIE     1       2       0
# WIF     0       0       1
# YUG    11       8       7
# ZIM     1       1       0
#
# [121 rows x 3 columns]

# %%
medals_pivot.sort_values(by = ['Gold'], ascending= False)
# Out:
#      Gold  Silver  Bronze
# NOC
# USA   412     304     272
# URS   151     117     103
# FRA   110     106     138
# ITA   104      89      97
# GER   103     121     110
# ..    ...     ...     ...
# SRB     0       1       1
# SEN     0       1       0
# UAR     0       1       1
# VEN     0       0       5
# WIF     0       0       1
#
# [121 rows x 3 columns]

# %%
medals = medals.get(['NOC','MEDAL','EVENT'])
medals.head()
# Out:
#     NOC   MEDAL                                   EVENT
# 3   DEN    Gold             Tug-Of-War Men's Tug-Of-War
# 37  FIN  Bronze  Swimming Men's 200 metres Breaststroke
# 38  FIN  Bronze  Swimming Men's 400 metres Breaststroke
# 40  FIN  Bronze             Ice Hockey Men's Ice Hockey
# 41  FIN  Bronze  Gymnastics Men's Individual All-Around

# %%
medals.pivot_table(index = 'NOC',columns = 'MEDAL', aggfunc= 'count', fill_value = 0, margins = True, margins_name= 'Total')
# Out:
#        EVENT
# MEDAL Bronze  Gold Silver Total
# NOC
# AHO        0     0      1     1
# ALG        2     1      1     4
# ANZ        3     2      3     8
# ARG       13    10     13    36
# ARM        5     1      3     9
# ...      ...   ...    ...   ...
# VIE        0     1      2     3
# WIF        1     0      0     1
# YUG        7    11      8    26
# ZIM        0     1      1     2
# Total   2110  2049   2009  6168
#
# [122 rows x 4 columns]

# %%
medals_pivot = medals.pivot_table(
    index="NOC",
    columns="MEDAL",
    aggfunc="count",
    fill_value=0,
)

# %%
medals_pivot.sum( axis = 1)
# Out:
# NOC
# AHO     1
# ALG     4
# ANZ     8
# ARG    36
# ARM     9
#        ..
# VEN     5
# VIE     3
# WIF     1
# YUG    26
# ZIM     2
# Length: 121, dtype: int64

# %%
medals_pivot['TOTAL'] = medals_pivot.sum( axis = 1)
medals_pivot
# Out:
#        EVENT             TOTAL
# MEDAL Bronze Gold Silver
# NOC
# AHO        0    0      1     1
# ALG        2    1      1     4
# ANZ        3    2      3     8
# ARG       13   10     13    36
# ARM        5    1      3     9
# ..       ...  ...    ...   ...
# VEN        5    0      0     5
# VIE        0    1      2     3
# WIF        1    0      0     1
# YUG        7   11      8    26
# ZIM        0    1      1     2
#
# [121 rows x 4 columns]

# %% [markdown]
# pivot table y melt

# %%
medals_pivot = medals.pivot_table(index = 'NOC', columns = 'MEDAL', aggfunc = 'count', fill_value= 0)
medals_pivot.columns = ['Bronze','Gold','Silver']
medals_pivot
# Out:
#      Bronze  Gold  Silver
# NOC
# AHO       0     0       1
# ALG       2     1       1
# ANZ       3     2       3
# ARG      13    10      13
# ARM       5     1       3
# ..      ...   ...     ...
# VEN       5     0       0
# VIE       0     1       2
# WIF       1     0       0
# YUG       7    11       8
# ZIM       0     1       1
#
# [121 rows x 3 columns]

# %%
medals_pivot = medals_pivot.reset_index()
medals_pivot
# Out:
#      NOC  Bronze  Gold  Silver
# 0    AHO       0     0       1
# 1    ALG       2     1       1
# 2    ANZ       3     2       3
# 3    ARG      13    10      13
# 4    ARM       5     1       3
# ..   ...     ...   ...     ...
# 116  VEN       5     0       0
# 117  VIE       0     1       2
# 118  WIF       1     0       0
# 119  YUG       7    11       8
# 120  ZIM       0     1       1
#
# [121 rows x 4 columns]

# %%
medals_melt = medals_pivot.melt(id_vars='NOC',value_vars= ['Bronze','Gold','Silver'], var_name= 'MEDAL', value_name = 'Count')
medals_melt
# Out:
#      NOC   MEDAL  Count
# 0    AHO  Bronze      0
# 1    ALG  Bronze      2
# 2    ANZ  Bronze      3
# 3    ARG  Bronze     13
# 4    ARM  Bronze      5
# ..   ...     ...    ...
# 358  VEN  Silver      0
# 359  VIE  Silver      2
# 360  WIF  Silver      0
# 361  YUG  Silver      8
# 362  ZIM  Silver      1
#
# [363 rows x 3 columns]

# %%
medals_melt.query('NOC == "ARG"')
# Out:
#      NOC   MEDAL  Count
# 3    ARG  Bronze     13
# 124  ARG    Gold     10
# 245  ARG  Silver     13

# %% [markdown]
# ***BEIJING 2008***
#
# El impacto de las olimpiadas de Beijing 2008 de China
#
# Fuente: https://www.chinabusinessreview.com/the-2008-olympics-impact-on-china/

# %%
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  ...          SPORT  \
# 0  CHN  1992 Summer  1992  ...     Basketball
# 1  CHN  2012 Summer  2012  ...           Judo
# 2  DEN  1920 Summer  1920  ...       Football
# 3  DEN  1900 Summer  1900  ...     Tug-Of-War
# 4  NED  1988 Winter  1988  ...  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
olympics_china = olympics.query('(NOC == "CHN") & (SEASON == "Summer")')
olympics_china.head()
# Out:
#         ID           NAME SEX   AGE  HEIGHT  WEIGHT   TEAM  NOC        GAMES  \
# 0        1      A Dijiang   M  24.0   180.0    80.0  China  CHN  1992 Summer
# 1        2       A Lamusi   M  23.0   170.0    60.0  China  CHN  2012 Summer
# 1072   602  Abudoureheman   M  22.0   182.0    75.0  China  CHN  2000 Summer
# 2611  1463      Ai Linuer   M  25.0   160.0    62.0  China  CHN  2004 Summer
# 2612  1464      Ai Yanhan   F  14.0   168.0    54.0  China  CHN  2016 Summer
#
#       YEAR  ...       SPORT                                     EVENT MEDAL  \
# 0     1992  ...  Basketball               Basketball Men's Basketball   NaN
# 1     2012  ...        Judo              Judo Men's Extra-Lightweight   NaN
# 1072  2000  ...      Boxing                 Boxing Men's Middleweight   NaN
# 2611  2004  ...   Wrestling  Wrestling Men's Lightweight, Greco-Roman   NaN
# 2612  2016  ...    Swimming     Swimming Women's 200 metres Freestyle   NaN
#
# ...

# %%
medals_china = olympics_china.dropna(subset = 'MEDAL')
medals_china.head()
# Out:
#           ID          NAME SEX   AGE  HEIGHT  WEIGHT   TEAM  NOC        GAMES  \
# 6437    3611   An Zhongxin   F  23.0   170.0    65.0  China  CHN  1996 Summer
# 11690   6381        Ba Yan   F  21.0   183.0    78.0  China  CHN  1984 Summer
# 14077   7597  Bao Yingying   F  24.0   172.0    67.0  China  CHN  2008 Summer
# 21260  11223    Bi Wenjing   F  14.0   142.0    35.0  China  CHN  1996 Summer
# 33513  17282    Cai Huijue   F  16.0   174.0    63.0  China  CHN  1996 Summer
#
#        YEAR  ...       SPORT                                         EVENT  \
# 6437   1996  ...    Softball                     Softball Women's Softball
# 11690  1984  ...  Basketball                 Basketball Women's Basketball
# 14077  2008  ...     Fencing                   Fencing Women's Sabre, Team
# 21260  1996  ...  Gymnastics                Gymnastics Women's Uneven Bars
# 33513  1996  ...    Swimming  Swimming Women's 4 x 100 metres Medley Relay
#
# ...

# %%
medals_china = medals_china.drop_duplicates( subset= ['GAMES', 'EVENT'])
medals_china.head()
# Out:
#           ID          NAME SEX   AGE  HEIGHT  WEIGHT   TEAM  NOC        GAMES  \
# 6437    3611   An Zhongxin   F  23.0   170.0    65.0  China  CHN  1996 Summer
# 11690   6381        Ba Yan   F  21.0   183.0    78.0  China  CHN  1984 Summer
# 14077   7597  Bao Yingying   F  24.0   172.0    67.0  China  CHN  2008 Summer
# 21260  11223    Bi Wenjing   F  14.0   142.0    35.0  China  CHN  1996 Summer
# 33513  17282    Cai Huijue   F  16.0   174.0    63.0  China  CHN  1996 Summer
#
#        YEAR  ...       SPORT                                         EVENT  \
# 6437   1996  ...    Softball                     Softball Women's Softball
# 11690  1984  ...  Basketball                 Basketball Women's Basketball
# 14077  2008  ...     Fencing                   Fencing Women's Sabre, Team
# 21260  1996  ...  Gymnastics                Gymnastics Women's Uneven Bars
# 33513  1996  ...    Swimming  Swimming Women's 4 x 100 metres Medley Relay
#
# ...

# %%
medals_china.get(['YEAR','MEDAL','EVENT']).groupby(['YEAR','MEDAL']).count()
# Out:
#              EVENT
# YEAR MEDAL
# 1984 Bronze      9
#      Gold       11
#      Silver      6
# 1988 Bronze     10
#      Gold        5
#      Silver      8
# 1992 Bronze     10
#      Gold       15
#      Silver     19
# 1996 Bronze     10
#      Gold       15
#      Silver     18
# 2000 Bronze      9
#      Gold       23
#      Silver     13
# 2004 Bronze     11
#      Gold       28
#      Silver     16
# 2008 Bronze     21
#      Gold       46
#      Silver     18
# 2012 Bronze     20
#      Gold       31
#      Silver     23
# 2016 Bronze     23
#      Gold       24
#      Silver     14

# %%
medals_count = medals_china.get(["YEAR", "MEDAL", "EVENT"]).groupby(["YEAR", "MEDAL"], as_index = False).count()
medals_count.head(20)
# Out:
#     YEAR   MEDAL  EVENT
# 0   1984  Bronze      9
# 1   1984    Gold     11
# 2   1984  Silver      6
# 3   1988  Bronze     10
# 4   1988    Gold      5
# 5   1988  Silver      8
# 6   1992  Bronze     10
# 7   1992    Gold     15
# 8   1992  Silver     19
# 9   1996  Bronze     10
# 10  1996    Gold     15
# 11  1996  Silver     18
# 12  2000  Bronze      9
# 13  2000    Gold     23
# 14  2000  Silver     13
# 15  2004  Bronze     11
# 16  2004    Gold     28
# 17  2004  Silver     16
# 18  2008  Bronze     21
# 19  2008    Gold     46

# %%
seaborn.barplot(data = medals_count, x= 'YEAR', y= 'EVENT', hue = 'MEDAL' ,errorbar = None, palette = 'plasma')
# Out:
# <Axes: xlabel='YEAR', ylabel='EVENT'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize= (15,10))
seaborn.barplot(data = medals_count, x= 'YEAR', y= 'EVENT', hue = 'MEDAL' ,errorbar = None, palette = 'plasma')
# Out:
# <Axes: xlabel='YEAR', ylabel='EVENT'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
seaborn.barplot(
    data=medals_count, x="YEAR", y="EVENT", hue="MEDAL", errorbar=None, palette="coolwarm", hue_order = ['Bronze','Silver','Gold']
)
# Out:
# <Axes: xlabel='YEAR', ylabel='EVENT'>

# %% [markdown]
# ***Participación de mujeres en las olimpiadas***

# %%
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  ...          SPORT  \
# 0  CHN  1992 Summer  1992  ...     Basketball
# 1  CHN  2012 Summer  2012  ...           Judo
# 2  DEN  1920 Summer  1920  ...       Football
# 3  DEN  1900 Summer  1900  ...     Tug-Of-War
# 4  NED  1988 Winter  1988  ...  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
olympics.isnull().sum()
# Out:
# ID                  0
# NAME                0
# SEX                 0
# AGE              9474
# HEIGHT          60171
# WEIGHT          62875
# TEAM                0
# NOC                 0
# GAMES               0
# YEAR                0
# SEASON              0
# CITY                0
# SPORT               0
# EVENT               0
# MEDAL          231333
# EVENTGAME           0
# BMI             64263
# OLYMPIC             0
# SEX_NUMERIC         0
# Adulto              0
# HEIGHT_MTS      60171
# NAME_LENGTH         0
# dtype: int64

# %%
olympics.get(['NAME','SEX','GAMES','YEAR', 'SEASON'])
olympics.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  ...          SPORT  \
# 0  CHN  1992 Summer  1992  ...     Basketball
# 1  CHN  2012 Summer  2012  ...           Judo
# 2  DEN  1920 Summer  1920  ...       Football
# 3  DEN  1900 Summer  1900  ...     Tug-Of-War
# 4  NED  1988 Winter  1988  ...  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
olympics_woman = olympics_woman.query('SEASON == "Summer"')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[168], line 1
# ----> 1 olympics_woman = olympics_woman.query('SEASON == "Summer"')
#
# NameError: name 'olympics_woman' is not defined

# %%
olympics_woman= olympics.drop_duplicates(subset = ['GAMES','ID'])
olympics_woman.head()
# Out:
#    ID                      NAME SEX   AGE  HEIGHT  WEIGHT            TEAM  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        GAMES  YEAR  ...          SPORT  \
# 0  CHN  1992 Summer  1992  ...     Basketball
# 1  CHN  2012 Summer  2012  ...           Judo
# 2  DEN  1920 Summer  1920  ...       Football
# 3  DEN  1900 Summer  1900  ...     Tug-Of-War
# 4  NED  1988 Winter  1988  ...  Speed Skating
#
#                               EVENT MEDAL  \
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# ...

# %%
olympics_pivot = olympics_woman.get(['YEAR','SEX','NAME']).pivot_table(index = 'YEAR',columns = 'SEX',aggfunc = 'count', fill_value=0)
olympics_pivot.head()
# Out:
#      NAME
# SEX     F     M
# YEAR
# 1896    0   176
# 1900   23  1201
# 1904    6   644
# 1906    6   835
# 1908   44  1980

# %%
olympics_pivot.columns = ['F','M']
olympics_pivot.head()
# Out:
#        F     M
# YEAR
# 1896   0   176
# 1900  23  1201
# 1904   6   644
# 1906   6   835
# 1908  44  1980

# %%
olympics_pivot['TOTAL'] = olympics_pivot.sum(axis = 1)
olympics_pivot.head()
# Out:
#        F     M        TOTAL  Porcentaje M
# YEAR
# 1896   0   176   176.000000      0.000000
# 1900  23  1201  1224.009395      0.009395
# 1904   6   644   650.004615      0.004615
# 1906   6   835   841.003567      0.003567
# 1908  44  1980  2024.010870      0.010870

# %%
olympics_pivot['PORCENTAJE_M'] = olympics_pivot['F'] / olympics_pivot['TOTAL']
olympics_pivot
# Out:
#     YEAR     F     M         TOTAL  Porcentaje M  PORCENTAJE_M
# 0   1896     0   176    176.000000      0.000000      0.000000
# 1   1900    23  1201   1224.009395      0.018791      0.018791
# 2   1904     6   644    650.004615      0.009231      0.009231
# 3   1906     6   835    841.003567      0.007134      0.007134
# 4   1908    44  1980   2024.010870      0.021739      0.021739
# 5   1912    53  2356   2409.011000      0.022001      0.022001
# 6   1920    78  2598   2676.014574      0.029148      0.029148
# 7   1924   169  3400   3569.023676      0.047352      0.047352
# 8   1928   340  3368   3708.045847      0.091693      0.091693
# 9   1932   222  1952   2174.051058      0.102114      0.102114
# 10  1936   441  4711   5152.042799      0.085597      0.085597
# 11  1948   523  4547   5070.051578      0.103155      0.103155
# 12  1952   630  4996   5626.055990      0.111979      0.111979
# 13  1956   516  3652   4168.061900      0.123799      0.123799
# ...

# %%
olympics_pivot = olympics_pivot.reset_index()
olympics_pivot.head()
# Out:
#    index  YEAR   F     M        TOTAL  Porcentaje M  PORCENTAJE_M
# 0      0  1896   0   176   176.000000      0.000000      0.000000
# 1      1  1900  23  1201  1224.009395      0.018791      0.018791
# 2      2  1904   6   644   650.004615      0.009231      0.009231
# 3      3  1906   6   835   841.003567      0.007134      0.007134
# 4      4  1908  44  1980  2024.010870      0.021739      0.021739

# %%
seaborn.lineplot(data = olympics_pivot, x = 'YEAR', y = 'PORCENTAJE_M')
# Out:
# <Axes: xlabel='YEAR', ylabel='PORCENTAJE_M'>

# %% [markdown]
# ***Tratamiento de valores nulos***

# %%
olympics.isnull().sum()
# Out:
# ID                  0
# NAME                0
# SEX                 0
# AGE              9474
# HEIGHT          60171
# WEIGHT          62875
# TEAM                0
# NOC                 0
# GAMES               0
# YEAR                0
# SEASON              0
# CITY                0
# SPORT               0
# EVENT               0
# MEDAL          231333
# EVENTGAME           0
# BMI             64263
# OLYMPIC             0
# SEX_NUMERIC         0
# Adulto              0
# HEIGHT_MTS      60171
# NAME_LENGTH         0
# dtype: int64

# %%
olympics['MEDAL'] = olympics['MEDAL'].fillna('NO MEDAL')
olympics.isnull().sum()
# Out:
# ID                 0
# NAME               0
# SEX                0
# AGE             9474
# HEIGHT         60171
# WEIGHT         62875
# TEAM               0
# NOC                0
# GAMES              0
# YEAR               0
# SEASON             0
# CITY               0
# SPORT              0
# EVENT              0
# MEDAL              0
# EVENTGAME          0
# BMI            64263
# OLYMPIC            0
# SEX_NUMERIC        0
# Adulto             0
# HEIGHT_MTS     60171
# NAME_LENGTH        0
# dtype: int64

# %%
olympics['AGE'].median()
# Out:
# np.float64(24.0)

# %%
olympics["AGE"] = olympics["AGE"].fillna(olympics["AGE"].median())

# %%
olympics.isnull().sum()
# Out:
# ID                 0
# NAME               0
# SEX                0
# AGE                0
# HEIGHT         60171
# WEIGHT         62875
# TEAM               0
# NOC                0
# GAMES              0
# YEAR               0
# SEASON             0
# CITY               0
# SPORT              0
# EVENT              0
# MEDAL              0
# EVENTGAME          0
# BMI            64263
# OLYMPIC            0
# SEX_NUMERIC        0
# Adulto             0
# HEIGHT_MTS     60171
# NAME_LENGTH        0
# dtype: int64

# %%
olympics_null = olympics[olympics['HEIGHT'].isnull()]
olympics_null.head()
# Out:
#     ID                            NAME SEX   AGE  HEIGHT  WEIGHT  \
# 2    3             Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4            Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 29  10  Einar Ferdinand "Einari" Aalto   M  26.0     NaN     NaN
# 35  15            Arvo Ossian Aaltonen   M  22.0     NaN     NaN
# 36  15            Arvo Ossian Aaltonen   M  22.0     NaN     NaN
#
#               TEAM  NOC        GAMES  YEAR  ...       SPORT  \
# 2          Denmark  DEN  1920 Summer  1920  ...    Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  ...  Tug-Of-War
# 29         Finland  FIN  1952 Summer  1952  ...    Swimming
# 35         Finland  FIN  1912 Summer  1912  ...    Swimming
# 36         Finland  FIN  1912 Summer  1912  ...    Swimming
#
#                                      EVENT     MEDAL  \
# 2                  Football Men's Football  NO MEDAL
# 3              Tug-Of-War Men's Tug-Of-War      Gold
# ...

# %%
olympics_null['SPORT'].unique()
# Out:
# array(['Football', 'Tug-Of-War', 'Swimming', 'Art Competitions',
#        'Speed Skating', 'Gymnastics', 'Water Polo', 'Hockey', 'Athletics',
#        'Fencing', 'Sailing', 'Shooting', 'Boxing', 'Cycling', 'Judo',
#        'Rowing', 'Modern Pentathlon', 'Weightlifting', 'Diving',
#        'Basketball', 'Golf', 'Taekwondo', 'Handball', 'Wrestling',
#        'Badminton', 'Tennis', 'Archery', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Cross Country Skiing', 'Nordic Combined',
#        'Figure Skating', 'Rhythmic Gymnastics', 'Bobsleigh',
#        'Equestrianism', 'Table Tennis', 'Canoeing', 'Ski Jumping',
#        'Synchronized Swimming', 'Curling', 'Rugby', 'Baseball',
#        'Lacrosse', 'Polo', 'Volleyball', 'Luge', 'Cricket', 'Racquets',
#        'Motorboating', 'Military Ski Patrol', 'Croquet', 'Softball',
#        'Freestyle Skiing', 'Skeleton', 'Jeu De Paume',
#        'Short Track Speed Skating', 'Roque', 'Alpinism', 'Rugby Sevens',
# ...

# %%
olympics_nulls = olympics[olympics['SPORT'].isin(['Cycling','Basketball'])]
olympics_nulls
# Out:
#             ID                             NAME SEX   AGE  HEIGHT  WEIGHT  \
# 0            1                        A Dijiang   M  24.0   180.0    80.0
# 149         56                       Ren Abadie   M  21.0     NaN     NaN
# 150         56                       Ren Abadie   M  21.0     NaN     NaN
# 152         58                 Georgi Abadzhiev   M   NaN     NaN     NaN
# 153         58                 Georgi Abadzhiev   M   NaN     NaN     NaN
# ...        ...                              ...  ..   ...     ...     ...
# 271003  135515     Adriaan "Adrie" Zwartepoorte   M  19.0     NaN     NaN
# 271026  135530                   Philip Zwiener   M  23.0   202.0    98.0
# 271075  135552  Jan (Johann-) Zybert (Siebert-)   M  20.0     NaN     NaN
# 271101  135562                       Milan Zyka   M  24.0   173.0    68.0
# 271110  135568           Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   TEAM  NOC        GAMES  YEAR  ...       SPORT  \
# ...

# %%
olympics_nulls['HEIGHT'].median()
# Out:
# np.float64(180.0)

# %%
olympics_nulls.groupby(["SPORT", "SEX"])["HEIGHT"].median()
# Out:
# SPORT       SEX
# Basketball  F      183.0
#             M      195.0
# Cycling     F      168.0
#             M      178.0
# Name: HEIGHT, dtype: float64

# %%
median_heights = olympics_nulls.groupby(["SPORT", "SEX"])["HEIGHT"].transform("median")

# %%
olympics_nulls['HEIGHT_IMPUTED'] = olympics_nulls['HEIGHT'].fillna(median_heights)
# Out:
# C:\Users\ooagu\AppData\Local\Temp\ipykernel_12304\532778421.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympics_nulls['HEIGHT_IMPUTED'] = olympics_nulls['HEIGHT'].fillna(median_heights)

# %%
pd.set_option("display.max_columns", None)

# %%
olympics_nulls.head()
# Out:
#      ID              NAME SEX   AGE  HEIGHT  WEIGHT      TEAM  NOC  \
# 0     1         A Dijiang   M  24.0   180.0    80.0     China  CHN
# 149  56        Ren Abadie   M  21.0     NaN     NaN    France  FRA
# 150  56        Ren Abadie   M  21.0     NaN     NaN    France  FRA
# 152  58  Georgi Abadzhiev   M   NaN     NaN     NaN  Bulgaria  BUL
# 153  58  Georgi Abadzhiev   M   NaN     NaN     NaN  Bulgaria  BUL
#
#            GAMES  YEAR  SEASON       CITY       SPORT  \
# 0    1992 Summer  1992  Summer  Barcelona  Basketball
# 149  1956 Summer  1956  Summer  Melbourne     Cycling
# 150  1956 Summer  1956  Summer  Melbourne     Cycling
# 152  1924 Summer  1924  Summer      Paris     Cycling
# 153  1924 Summer  1924  Summer      Paris     Cycling
#
#                                    EVENT MEDAL  \
# 0            Basketball Men's Basketball   NaN
# 149  Cycling Men's Road Race, Individual   NaN
# 150        Cycling Men's Road Race, Team  Gold
# ...

# %% [markdown]
# Datatimes
#
# Taxi trip duration: https://www.kaggle.com/c/nyc-taxi-trip-duration

# %%
taxis = pd.read_csv(r"..\datasets\04-manipulacion-dataframes-pandas\taxis.csv", nrows = 10000)

# %%
taxis.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# ...

# %%
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                10000 non-null  object
#  1   fare_amount        10000 non-null  float64
#  2   pickup_datetime    10000 non-null  object
#  3   pickup_longitude   10000 non-null  float64
#  4   pickup_latitude    10000 non-null  float64
#  5   dropoff_longitude  10000 non-null  float64
#  6   dropoff_latitude   10000 non-null  float64
#  7   passenger_count    10000 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 625.1+ KB

# %%
date_0 = taxis.loc[0,'pickup_datetime']
date_0
# Out:
# '2009-06-15 17:26:21 UTC'

# %%
type(date_0)
# Out:
# str

# %%
date_0[:4]
# Out:
# '2009'

# %%
taxis['pickup_datetime_dt'] = pd.to_datetime(taxis['pickup_datetime'])
taxis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   key                 10000 non-null  object
#  1   fare_amount         10000 non-null  float64
#  2   pickup_datetime     10000 non-null  object
#  3   pickup_longitude    10000 non-null  float64
#  4   pickup_latitude     10000 non-null  float64
#  5   dropoff_longitude   10000 non-null  float64
#  6   dropoff_latitude    10000 non-null  float64
#  7   passenger_count     10000 non-null  int64
#  8   pickup_datetime_dt  10000 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), float64(5), int64(1), object(2)
# memory usage: 703.3+ KB

# %%
taxis[['pickup_datetime', 'pickup_datetime_dt']].head()
# Out:
#            pickup_datetime        pickup_datetime_dt
# 0  2009-06-15 17:26:21 UTC 2009-06-15 17:26:21+00:00
# 1  2010-01-05 16:52:16 UTC 2010-01-05 16:52:16+00:00
# 2  2011-08-18 00:35:00 UTC 2011-08-18 00:35:00+00:00
# 3  2012-04-21 04:30:42 UTC 2012-04-21 04:30:42+00:00
# 4  2010-03-09 07:51:00 UTC 2010-03-09 07:51:00+00:00

# %%
taxis["year"] = taxis["pickup_datetime_dt"].dt.year
taxis["month"] = taxis["pickup_datetime_dt"].dt.month
taxis["day"] = taxis["pickup_datetime_dt"].dt.day
taxis["weekday"] = taxis["pickup_datetime_dt"].dt.weekday
taxis["weekday_name"] = taxis["pickup_datetime_dt"].dt.day_name()

# %%
taxis.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count        pickup_datetime_dt  year  month  day  weekday  \
# ...

# %% [markdown]
# datetimes format
#
# date format: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior

# %%
dates = pd.read_csv(r"..\datasets\04-manipulacion-dataframes-pandas\dates.csv")
dates.head()
# Out:
#                    dates
# 0     Sunday 01-Mar-2020
# 1     Monday 02-Mar-2020
# 2    Tuesday 03-Mar-2020
# 3  Wednesday 04-Mar-2020
# 4   Thursday 05-Mar-2020

# %%
dates['datetime']= pd.to_datetime(dates['dates'])
dates.head()
# Out:
#                    dates   datetime
# 0     Sunday 01-Mar-2020 2020-03-01
# 1     Monday 02-Mar-2020 2020-03-02
# 2    Tuesday 03-Mar-2020 2020-03-03
# 3  Wednesday 04-Mar-2020 2020-03-04
# 4   Thursday 05-Mar-2020 2020-03-05

# %%
dates['month'] = dates['datetime'].dt.month
dates['day_name'] = dates['datetime'].dt.dayname()

# %%
dates['datetime_format'] = pd.to_datetime(dates['dates'], format = '%A %d-%b-%Y')
dates.head()
# Out:
#                    dates   datetime  month  day datetime_format
# 0     Sunday 01-Mar-2020 2020-03-01      3    1      2020-03-01
# 1     Monday 02-Mar-2020 2020-03-02      3    2      2020-03-02
# 2    Tuesday 03-Mar-2020 2020-03-03      3    3      2020-03-03
# 3  Wednesday 04-Mar-2020 2020-03-04      3    4      2020-03-04
# 4   Thursday 05-Mar-2020 2020-03-05      3    5      2020-03-05

# %%
dates['datetime_format'].dt.hour.head()
#.dt.minute
#.dt.second
#.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: datetime_format, dtype: int32

# %% [markdown]
# '2023-02-01' --> '20230201' --> '01022023'
#
# Formas en las que podemos cambiar el formato fecha, ejemplo

# %%
dates['fecha'] = dates.datetime_format.dt.strftime('%d%m%Y')
dates.head()
# Out:
#                    dates   datetime  month  day datetime_format     fecha
# 0     Sunday 01-Mar-2020 2020-03-01      3    1      2020-03-01  01032020
# 1     Monday 02-Mar-2020 2020-03-02      3    2      2020-03-02  02032020
# 2    Tuesday 03-Mar-2020 2020-03-03      3    3      2020-03-03  03032020
# 3  Wednesday 04-Mar-2020 2020-03-04      3    4      2020-03-04  04032020
# 4   Thursday 05-Mar-2020 2020-03-05      3    5      2020-03-05  05032020

# %%
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   dates            31 non-null     object
#  1   datetime         31 non-null     datetime64[ns]
#  2   month            31 non-null     int32
#  3   day              31 non-null     int32
#  4   datetime_format  31 non-null     datetime64[ns]
#  5   fecha            31 non-null     object
# dtypes: datetime64[ns](2), int32(2), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# Hay que ver que los formatos fecha con este cambio se devuelven con tipo object(osea string para este caso)
